# %% [markdown]
# ## 코드정보 공공데이터 불러오기

# %%
from urllib.request import Request,urlopen
from urllib.parse import urlencode,quote_plus
import pandas as pd
import json

skey = 'EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D'
#skey = 'EbwPIaTQ+n53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS+LvYw4mTX2ytwazyZbfe6SzIXv3YZKA=='
resultType = 'json'
#선거공약서 제출코드(SgTypecode) : 1(대통령선거), 3(시∙도시자선거),4(구∙시∙군의장선거), 11(교육감선거)
pageNo = '1'
numOfRows = '100'

url = 'http://apis.data.go.kr/9760000/CommonCodeService/getCommonSgCodeList'
params = f'?&numOfRows={numOfRows}&resultType={resultType}&serviceKey={skey}&pageNo={pageNo}'
query = url + params
#print(query)

request = Request(query)
request.get_method = lambda:'GET'
response_body = urlopen(request).read()
#print(response_body)

response_dict = json.loads(response_body.decode('utf-8'))
response_dict
items = response_dict['getCommonSgCodeList']['item']

df = pd.DataFrame(items)
df
# Out:
#    NUM     SG_ID      SG_NAME SG_TYPECODE SG_VOTEDATE
# 0    1  20021219   제16대 대통령선거           0    20021219
# 1    2  20021219        대통령선거           1    20021219
# 2    3  20040415  제17대 국회의원선거           0    20040415
# 3    4  20040415       국회의원선거           2    20040415
# 4    5  20040415   비례대표국회의원선거           7    20040415
# ..  ..       ...          ...         ...         ...
# 75  76  20220601  구·시·군의회의원선거           6    20220601
# 76  77  20220601   광역의원비례대표선거           8    20220601
# 77  78  20220601   기초의원비례대표선거           9    20220601
# 78  79  20220601       교육의원선거          10    20220601
# 79  80  20220601        교육감선거          11    20220601
#
# [80 rows x 5 columns]

# %%
from urllib.request import Request,urlopen
from urllib.parse import urlencode,quote_plus
import pandas as pd
import json

skey = 'EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D'
#skey = 'EbwPIaTQ+n53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS+LvYw4mTX2ytwazyZbfe6SzIXv3YZKA=='
resultType = 'json'
#선거공약서 제출코드(SgTypecode) : 1(대통령선거), 3(시∙도시자선거),4(구∙시∙군의장선거), 11(교육감선거)
pageNo = '1'
numOfRows = '100'

url = 'http://apis.data.go.kr/9760000/CommonCodeService/getCommonSgCodeList'
params = f'?&numOfRows={numOfRows}&resultType={resultType}&serviceKey={skey}&pageNo={pageNo}'
query = url + params
#print(query)

request = Request(query)
request.get_method = lambda:'GET'
response_body = urlopen(request).read()
#print(response_body)

response_dict = json.loads(response_body.decode('utf-8'))
response_dict
#items = response_dict['getCommonSgCodeList']['item']

#df = pd.DataFrame(items)
#df
# Out:
# {'getCommonSgCodeList': {'header': {'code': 'INFO-00',
#    'message': 'NORMAL SERVICE'},
#   'item': [{'NUM': '1',
#     'SG_ID': '20021219',
#     'SG_NAME': '제16대 대통령선거',
#     'SG_TYPECODE': '0',
#     'SG_VOTEDATE': '20021219'},
#    {'NUM': '2',
#     'SG_ID': '20021219',
#     'SG_NAME': '대통령선거',
#     'SG_TYPECODE': '1',
#     'SG_VOTEDATE': '20021219'},
#    {'NUM': '3',
#     'SG_ID': '20040415',
#     'SG_NAME': '제17대 국회의원선거',
#     'SG_TYPECODE': '0',
#     'SG_VOTEDATE': '20040415'},
#    {'NUM': '4',
#     'SG_ID': '20040415',
#     'SG_NAME': '국회의원선거',
#     'SG_TYPECODE': '2',
#     'SG_VOTEDATE': '20040415'},
#    {'NUM': '5',
#     'SG_ID': '20040415',
#     'SG_NAME': '비례대표국회의원선거',
#     'SG_TYPECODE': '7',
#     'SG_VOTEDATE': '20040415'},
#    {'NUM': '6',
#     'SG_ID': '20071219',
#     'SG_NAME': '제17대 대통령선거',
#     'SG_TYPECODE': '0',
#     'SG_VOTEDATE': '20071219'},
#    {'NUM': '7',
#     'SG_ID': '20071219',
#     'SG_NAME': '대통령선거',
#     'SG_TYPECODE': '1',
#     'SG_VOTEDATE': '20071219'},
#    {'NUM': '8',
#     'SG_ID': '20080409',
#     'SG_NAME': '제18대 국회의원선거',
#     'SG_TYPECODE': '0',
#     'SG_VOTEDATE': '20080409'},
#    {'NUM': '9',
#     'SG_ID': '20080409',
#     'SG_NAME': '국회의원선거',
#     'SG_TYPECODE': '2',
#     'SG_VOTEDATE': '20080409'},
#    {'NUM': '10',
#     'SG_ID': '20080409',
#     'SG_NAME': '비례대표국회의원선거',
#     'SG_TYPECODE': '7',
#     'SG_VOTEDATE': '20080409'},
#    {'NUM': '11',
#     'SG_ID': '20100602',
#     'SG_NAME': '제5회 전국동시지방선거',
#     'SG_TYPECODE': '0',
#     'SG_VOTEDATE': '20100602'},
#    {'NUM': '12',
#     'SG_ID': '20100602',
#     'SG_NAME': '시·도지사선거',
#     'SG_TYPECODE': '3',
#     'SG_VOTEDATE': '20100602'},
#    {'NUM': '13',
#     'SG_ID': '20100602',
#     'SG_NAME': '구·시·군의장선거',
#     'SG_TYPECODE': '4',
#     'SG_VOTEDATE': '20100602'},
#    {'NUM': '14',
#     'SG_ID': '20100602',
#     'SG_NAME': '시·도의회의원선거',
#     'SG_TYPECODE': '5',
#     'SG_VOTEDATE': '20100602'},
#    {'NUM': '15',
#     'SG_ID': '20100602',
#     'SG_NAME': '구·시·군의회의원선거',
#     'SG_TYPECODE': '6',
#     'SG_VOTEDATE': '20100602'},
#    {'NUM': '16',
#     'SG_ID': '20100602',
#     'SG_NAME': '광역의원비례대표선거',
#     'SG_TYPECODE': '8',
#     'SG_VOTEDATE': '20100602'},
#    {'NUM': '17',
#     'SG_ID': '20100602',
#     'SG_NAME': '기초의원비례대표선거',
#     'SG_TYPECODE': '9',
#     'SG_VOTEDATE': '20100602'},
#    {'NUM': '18',
#     'SG_ID': '20100602',
#     'SG_NAME': '교육의원선거',
#     'SG_TYPECODE': '10',
#     'SG_VOTEDATE': '20100602'},
#    {'NUM': '19',
#     'SG_ID': '20100602',
#     'SG_NAME': '교육감선거',
#     'SG_TYPECODE': '11',
#     'SG_VOTEDATE': '20100602'},
#    {'NUM': '20',
#     'SG_ID': '20120411',
#     'SG_NAME': '제19대 국회의원선거',
#     'SG_TYPECODE': '0',
#     'SG_VOTEDATE': '20120411'},
#    {'NUM': '21',
#     'SG_ID': '20120411',
#     'SG_NAME': '국회의원선거',
#     'SG_TYPECODE': '2',
#     'SG_VOTEDATE': '20120411'},
#    {'NUM': '22',
#     'SG_ID': '20120411',
#     'SG_NAME': '비례대표국회의원선거',
#     'SG_TYPECODE': '7',
#     'SG_VOTEDATE': '20120411'},
#    {'NUM': '23',
#     'SG_ID': '20121219',
#     'SG_NAME': '제18대 대통령선거',
#     'SG_TYPECODE': '0',
#     'SG_VOTEDATE': '20121219'},
#    {'NUM': '24',
#     'SG_ID': '20121219',
#     'SG_NAME': '대통령선거',
#     'SG_TYPECODE': '1',
#     'SG_VOTEDATE': '20121219'},
#    {'NUM': '25',
#     'SG_ID': '20140604',
#     'SG_NAME': '제6회 전국동시지방선거',
#     'SG_TYPECODE': '0',
#     'SG_VOTEDATE': '20140604'},
#    {'NUM': '26',
#     'SG_ID': '20140604',
#     'SG_NAME': '시·도지사선거',
#     'SG_TYPECODE': '3',
#     'SG_VOTEDATE': '20140604'},
#    {'NUM': '27',
#     'SG_ID': '20140604',
#     'SG_NAME': '구·시·군의 장선거',
#     'SG_TYPECODE': '4',
#     'SG_VOTEDATE': '20140604'},
#    {'NUM': '28',
#     'SG_ID': '20140604',
#     'SG_NAME': '시·도의회의원선거',
#     'SG_TYPECODE': '5',
#     'SG_VOTEDATE': '20140604'},
#    {'NUM': '29',
#     'SG_ID': '20140604',
#     'SG_NAME': '구·시·군의회의원선거',
#     'SG_TYPECODE': '6',
#     'SG_VOTEDATE': '20140604'},
#    {'NUM': '30',
#     'SG_ID': '20140604',
#     'SG_NAME': '광역의원비례대표선거',
#     'SG_TYPECODE': '8',
#     'SG_VOTEDATE': '20140604'},
#    {'NUM': '31',
#     'SG_ID': '20140604',
#     'SG_NAME': '기초의원비례대표선거',
#     'SG_TYPECODE': '9',
#     'SG_VOTEDATE': '20140604'},
#    {'NUM': '32',
#     'SG_ID': '20140604',
#     'SG_NAME': '교육의원선거',
#     'SG_TYPECODE': '10',
#     'SG_VOTEDATE': '20140604'},
#    {'NUM': '33',
#     'SG_ID': '20140604',
#     'SG_NAME': '교육감선거',
#     'SG_TYPECODE': '11',
#     'SG_VOTEDATE': '20140604'},
#    {'NUM': '34',
#     'SG_ID': '20160413',
#     'SG_NAME': '제20대 국회의원선거',
#     'SG_TYPECODE': '0',
#     'SG_VOTEDATE': '20160413'},
#    {'NUM': '35',
#     'SG_ID': '20160413',
#     'SG_NAME': '국회의원선거',
#     'SG_TYPECODE': '2',
#     'SG_VOTEDATE': '20160413'},
#    {'NUM': '36',
#     'SG_ID': '20160413',
#     'SG_NAME': '구·시·군의장선거',
#     'SG_TYPECODE': '4',
#     'SG_VOTEDATE': '20160413'},
#    {'NUM': '37',
#     'SG_ID': '20160413',
#     'SG_NAME': '시·도의회의원선거',
#     'SG_TYPECODE': '5',
#     'SG_VOTEDATE': '20160413'},
#    {'NUM': '38',
#     'SG_ID': '20160413',
#     'SG_NAME': '구·시·군의회의원선거',
#     'SG_TYPECODE': '6',
#     'SG_VOTEDATE': '20160413'},
#    {'NUM': '39',
#     'SG_ID': '20160413',
#     'SG_NAME': '비례대표국회의원선거',
#     'SG_TYPECODE': '7',
#     'SG_VOTEDATE': '20160413'},
#    {'NUM': '40',
#     'SG_ID': '20170509',
#     'SG_NAME': '제19대 대통령선거',
#     'SG_TYPECODE': '0',
#     'SG_VOTEDATE': '20170509'},
#    {'NUM': '41',
#     'SG_ID': '20170509',
#     'SG_NAME': '대통령선거',
#     'SG_TYPECODE': '1',
#     'SG_VOTEDATE': '20170509'},
#    {'NUM': '42',
#     'SG_ID': '20170509',
#     'SG_NAME': '시·도의회의원선거',
#     'SG_TYPECODE': '5',
#     'SG_VOTEDATE': '20170509'},
#    {'NUM': '43',
#     'SG_ID': '20170509',
#     'SG_NAME': '구·시·군의회의원선거',
#     'SG_TYPECODE': '6',
#     'SG_VOTEDATE': '20170509'},
#    {'NUM': '44',
#     'SG_ID': '20180613',
#     'SG_NAME': '제7회 전국동시지방선거',
#     'SG_TYPECODE': '0',
#     'SG_VOTEDATE': '20180613'},
#    {'NUM': '45',
#     'SG_ID': '20180613',
#     'SG_NAME': '국회의원선거',
#     'SG_TYPECODE': '2',
#     'SG_VOTEDATE': '20180613'},
#    {'NUM': '46',
#     'SG_ID': '20180613',
#     'SG_NAME': '시·도지사선거',
#     'SG_TYPECODE': '3',
#     'SG_VOTEDATE': '20180613'},
#    {'NUM': '47',
#     'SG_ID': '20180613',
#     'SG_NAME': '구·시·군의 장선거',
#     'SG_TYPECODE': '4',
#     'SG_VOTEDATE': '20180613'},
#    {'NUM': '48',
#     'SG_ID': '20180613',
#     'SG_NAME': '시·도의회의원선거',
#     'SG_TYPECODE': '5',
#     'SG_VOTEDATE': '20180613'},
#    {'NUM': '49',
#     'SG_ID': '20180613',
#     'SG_NAME': '구·시·군의회의원선거',
#     'SG_TYPECODE': '6',
#     'SG_VOTEDATE': '20180613'},
#    {'NUM': '50',
#     'SG_ID': '20180613',
#     'SG_NAME': '광역의원비례대표선거',
#     'SG_TYPECODE': '8',
#     'SG_VOTEDATE': '20180613'},
#    {'NUM': '51',
#     'SG_ID': '20180613',
#     'SG_NAME': '기초의원비례대표선거',
#     'SG_TYPECODE': '9',
#     'SG_VOTEDATE': '20180613'},
#    {'NUM': '52',
#     'SG_ID': '20180613',
#     'SG_NAME': '교육의원선거',
#     'SG_TYPECODE': '10',
#     'SG_VOTEDATE': '20180613'},
#    {'NUM': '53',
#     'SG_ID': '20180613',
#     'SG_NAME': '교육감선거',
#     'SG_TYPECODE': '11',
#     'SG_VOTEDATE': '20180613'},
#    {'NUM': '54',
#     'SG_ID': '20190403',
#     'SG_NAME': '2019년 보궐선거',
#     'SG_TYPECODE': '0',
#     'SG_VOTEDATE': '20190403'},
#    {'NUM': '55',
#     'SG_ID': '20190403',
#     'SG_NAME': '국회의원선거',
#     'SG_TYPECODE': '2',
#     'SG_VOTEDATE': '20190403'},
#    {'NUM': '56',
#     'SG_ID': '20190403',
#     'SG_NAME': '구·시·군의회의원선거',
#     'SG_TYPECODE': '6',
#     'SG_VOTEDATE': '20190403'},
#    {'NUM': '57',
#     'SG_ID': '20200415',
#     'SG_NAME': '제21대 국회의원선거',
#     'SG_TYPECODE': '0',
#     'SG_VOTEDATE': '20200415'},
#    {'NUM': '58',
#     'SG_ID': '20200415',
#     'SG_NAME': '국회의원선거',
#     'SG_TYPECODE': '2',
#     'SG_VOTEDATE': '20200415'},
#    {'NUM': '59',
#     'SG_ID': '20200415',
#     'SG_NAME': '구·시·군의 장선거',
#     'SG_TYPECODE': '4',
#     'SG_VOTEDATE': '20200415'},
#    {'NUM': '60',
#     'SG_ID': '20200415',
#     'SG_NAME': '시·도의회의원선거',
#     'SG_TYPECODE': '5',
#     'SG_VOTEDATE': '20200415'},
#    {'NUM': '61',
#     'SG_ID': '20200415',
#     'SG_NAME': '구·시·군의회의원선거',
#     'SG_TYPECODE': '6',
#     'SG_VOTEDATE': '20200415'},
#    {'NUM': '62',
#     'SG_ID': '20200415',
#     'SG_NAME': '비례대표국회의원선거',
#     'SG_TYPECODE': '7',
#     'SG_VOTEDATE': '20200415'},
#    {'NUM': '63',
#     'SG_ID': '20210407',
#     'SG_NAME': '2021년 재·보궐선거',
#     'SG_TYPECODE': '0',
#     'SG_VOTEDATE': '20210407'},
#    {'NUM': '64',
#     'SG_ID': '20210407',
#     'SG_NAME': '시·도지사선거',
#     'SG_TYPECODE': '3',
#     'SG_VOTEDATE': '20210407'},
#    {'NUM': '65',
#     'SG_ID': '20210407',
#     'SG_NAME': '구·시·군의 장선거',
#     'SG_TYPECODE': '4',
#     'SG_VOTEDATE': '20210407'},
#    {'NUM': '66',
#     'SG_ID': '20210407',
#     'SG_NAME': '시·도의회의원선거',
#     'SG_TYPECODE': '5',
#     'SG_VOTEDATE': '20210407'},
#    {'NUM': '67',
#     'SG_ID': '20210407',
#     'SG_NAME': '구·시·군의회의원선거',
#     'SG_TYPECODE': '6',
#     'SG_VOTEDATE': '20210407'},
#    {'NUM': '68',
#     'SG_ID': '20220309',
#     'SG_NAME': '제20대 대통령선거',
#     'SG_TYPECODE': '0',
#     'SG_VOTEDATE': '20220309'},
#    {'NUM': '69',
#     'SG_ID': '20220309',
#     'SG_NAME': '대통령선거',
#     'SG_TYPECODE': '1',
#     'SG_VOTEDATE': '20220309'},
#    {'NUM': '70',
#     'SG_ID': '20220309',
#     'SG_NAME': '국회의원선거',
#     'SG_TYPECODE': '2',
#     'SG_VOTEDATE': '20220309'},
#    {'NUM': '71',
#     'SG_ID': '20220601',
#     'SG_NAME': '제8회 전국동시지방선거',
#     'SG_TYPECODE': '0',
#     'SG_VOTEDATE': '20220601'},
#    {'NUM': '72',
#     'SG_ID': '20220601',
#     'SG_NAME': '국회의원선거',
#     'SG_TYPECODE': '2',
#     'SG_VOTEDATE': '20220601'},
#    {'NUM': '73',
#     'SG_ID': '20220601',
#     'SG_NAME': '시·도지사선거',
#     'SG_TYPECODE': '3',
#     'SG_VOTEDATE': '20220601'},
#    {'NUM': '74',
#     'SG_ID': '20220601',
#     'SG_NAME': '구·시·군의 장선거',
#     'SG_TYPECODE': '4',
#     'SG_VOTEDATE': '20220601'},
#    {'NUM': '75',
#     'SG_ID': '20220601',
#     'SG_NAME': '시·도의회의원선거',
#     'SG_TYPECODE': '5',
#     'SG_VOTEDATE': '20220601'},
#    {'NUM': '76',
#     'SG_ID': '20220601',
#     'SG_NAME': '구·시·군의회의원선거',
#     'SG_TYPECODE': '6',
#     'SG_VOTEDATE': '20220601'},
#    {'NUM': '77',
#     'SG_ID': '20220601',
#     'SG_NAME': '광역의원비례대표선거',
#     'SG_TYPECODE': '8',
#     'SG_VOTEDATE': '20220601'},
#    {'NUM': '78',
#     'SG_ID': '20220601',
#     'SG_NAME': '기초의원비례대표선거',
#     'SG_TYPECODE': '9',
#     'SG_VOTEDATE': '20220601'},
#    {'NUM': '79',
#     'SG_ID': '20220601',
#     'SG_NAME': '교육의원선거',
#     'SG_TYPECODE': '10',
#     'SG_VOTEDATE': '20220601'},
#    {'NUM': '80',
#     'SG_ID': '20220601',
#     'SG_NAME': '교육감선거',
#     'SG_TYPECODE': '11',
#     'SG_VOTEDATE': '20220601'}],
#   'rows': None,
#   'numOfRows': 100,
#   'pageNo': 1,
#   'totalCount': 80}}

# %% [markdown]
# ### 선거별 아이디=날짜 파악 (21.04.07~22.06.01)

# %%
df['SG_ID'].unique()
# Out:
# array(['20021219', '20040415', '20071219', '20080409', '20100602',
#        '20120411', '20121219', '20140604', '20160413', '20170509',
#        '20180613', '20190403', '20200415', '20210407', '20220309',
#        '20220601'], dtype=object)

# %%
df1 = df.loc[df['SG_ID']=='20210407',:]
df1
# Out:
#    NUM     SG_ID       SG_NAME SG_TYPECODE SG_VOTEDATE
# 62  63  20210407  2021년 재·보궐선거           0    20210407
# 63  64  20210407       시·도지사선거           3    20210407
# 64  65  20210407    구·시·군의 장선거           4    20210407
# 65  66  20210407     시·도의회의원선거           5    20210407
# 66  67  20210407   구·시·군의회의원선거           6    20210407

# %%
df2 = df.loc[df['SG_ID']=='20220309',:]
df2
# Out:
#    NUM     SG_ID     SG_NAME SG_TYPECODE SG_VOTEDATE
# 67  68  20220309  제20대 대통령선거           0    20220309
# 68  69  20220309       대통령선거           1    20220309
# 69  70  20220309      국회의원선거           2    20220309

# %%
df3 = df.loc[df['SG_ID']=='20220601',:]
df3
# Out:
#    NUM     SG_ID       SG_NAME SG_TYPECODE SG_VOTEDATE
# 70  71  20220601  제8회 전국동시지방선거           0    20220601
# 71  72  20220601        국회의원선거           2    20220601
# 72  73  20220601       시·도지사선거           3    20220601
# 73  74  20220601    구·시·군의 장선거           4    20220601
# 74  75  20220601     시·도의회의원선거           5    20220601
# 75  76  20220601   구·시·군의회의원선거           6    20220601
# 76  77  20220601    광역의원비례대표선거           8    20220601
# 77  78  20220601    기초의원비례대표선거           9    20220601
# 78  79  20220601        교육의원선거          10    20220601
# 79  80  20220601         교육감선거          11    20220601

# %% [markdown]
# ### 사용할 SG_ID, SG_VOTEDATE = '20210407','20220309','20220601'

# %% [markdown]
# ## x당선인 정보 활용x

# %%
from urllib.request import Request,urlopen
import urllib.request
from urllib.parse import urlencode,quote_plus
import pandas as pd
import json

skey ='EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D'
resultType = 'json'
sgId='20220601'
sgTypecode='3'
 
    #선거공약서 제출코드(SgTypecode) : 3(시∙도시자선거),4(구∙시∙군의장선거)

#pageNo ='1'
#numOfRows ='100'

url = 'http://apis.data.go.kr/9760000/WinnerInfoInqireService2/getWinnerInfoInqire'
params = f'?resultType={resultType}&serviceKey={skey}&sgId={sgId}&sgTypecode={sgTypecode}'
query = url + params
#print(query)

request = Request(query)
request.get_method = lambda:'GET'
response_body = urlopen(request).read()
#print(response_body)

response_dict = json.loads(response_body.decode('utf-8'))
response_dict
items = response_dict['getWinnerInfoInqire']['item']

df = pd.DataFrame(items)
df
# Out:
#   NUM     SG_ID SG_TYPECODE     HUBOID SGG_NAME SD_NAME WIW_NAME GIHO  \
# 0   1  20220601           3  100149260    서울특별시   서울특별시             2
# 1   2  20220601           3  100149514    부산광역시   부산광역시             2
# 2   3  20220601           3  100147274    대구광역시   대구광역시             2
# 3   4  20220601           3  100139645    인천광역시   인천광역시             2
# 4   5  20220601           3  100140244    광주광역시   광주광역시             1
# 5   6  20220601           3  100139063    대전광역시   대전광역시             2
# 6   7  20220601           3  100139025    울산광역시   울산광역시             2
# 7   8  20220601           3  100145752      경기도     경기도             1
# 8   9  20220601           3  100141401      강원도     강원도             2
# 9  10  20220601           3  100143970     충청북도    충청북도             2
#
#   GIHO_SANGSE JD_NAME  ... AGE                  ADDR JOB_ID     JOB EDU_ID  \
# 0                국민의힘  ...  61       서울특별시 광진구 능동로4길     73  서울특별시장    221
# 1                국민의힘  ...  62   부산광역시 해운대구 달맞이길65번길     73  부산광역시장    221
# 2                국민의힘  ...  67         대구광역시 수성구 수성로     75     정치인     68
# 3                국민의힘  ...  64         인천광역시 남동구 논현로     75     정당인     69
# 4              더불어민주당  ...  57          광주광역시 북구 대천로     75     정당인    221
# 5                국민의힘  ...  57          대전광역시 동구 용운로     75     정당인    221
# 6                국민의힘  ...  64       울산광역시 남구 북부순환도로     75     정당인    221
# 7              더불어민주당  ...  65   경기도 수원시 영통구 도청로18번길     75     정당인    221
# 8                국민의힘  ...  57     강원도 춘천시 동내면 춘천순환로     75     정당인     68
# 9                국민의힘  ...  67  충청북도 괴산군 청천면 도경로후영6길     75     정당인    221
#
#                                             EDU                    CAREER1  \
# 0                          고려대학교 법학대학원 졸업(법학박사)             (현)제38대 서울특별시장
# 1                  고려대학교 대학원 사회학과 박사과정 졸업(문학박사)                  (전)국회사무총장
# 2                            고려대학교 법과대학 행정학과 졸업  (전) 제15,16,17,18,21대 국회의원
# 3                        연세대학교 대학원 정치학과 박사과정 수료                  (전)인천광역시장
# 4                        전남대학교 행정대학원 졸업(행정학 석사)                (전)청와대 정무수석
# 5                     대전대학교 대학원 행정학과 졸업(행정학 박사)     (전)제19,20대 국회의원(대전 동구)
# 6                         울산대학교 일반대학원 졸업(행정학박사)     (전)울산광역시 남구청장(민선 3,4대)
# 7  미국 미시간대학교 대학원 졸업(정책학박사, 1989. 9. ~ 1993. 6.)       (전) 경제부총리 겸 기획재정부 장관
# 8                            서울대학교 법과대학 공법학과 졸업            (전)19, 20대 국회의원
# 9                         연세대학교 경제대학원 졸업(경제학석사)          (전)윤석열대통령당선인 특별고문
#
#                     CAREER2    DUGSU DUGYUL
# 0              (전)제16대 국회의원  2608277  59.05
# 1                 (현)부산광역시장   938601  66.36
# 2  (전) 제20대 대통령선거 국민의힘 경선후보   685159  78.75
# 3                (전)행정안전부장관   634250  51.76
# 4  (전)3선 국회의원(제17, 18, 19대)   334699  74.91
# 5        (전)윤석열 국민캠프 조직1본부장   310035  51.19
# 6          (전)울산광역시 남구의회 의장   290563  59.78
# 7              (전) 아주대학교 총장  2827593  49.06
# 8             (전)춘천지검 원주지청장   409461  54.07
# 9                (전)과학기술부장관   395517  58.19
#
# [10 rows x 24 columns]

# %% [markdown]
# ## 후보자 정보

# %%
from urllib.request import Request,urlopen
from urllib.parse import urlencode,quote_plus
import pandas as pd
import json


skey ='EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D'
#skey ='EbwPIaTQ+n53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS+LvYw4mTX2ytwazyZbfe6SzIXv3YZKA=='

resultType = 'json'
sgId='20220601'
sgTypecode='3'

url = 'http://apis.data.go.kr/9760000/PofelcddInfoInqireService/getPofelcddRegistSttusInfoInqire'
params = f'?sgId={sgId}&sgTypecode={sgTypecode}&resultType={resultType}&serviceKey={skey}'
query = url + params
#print(query)

request = Request(query)
request.get_method = lambda:'GET'
response_body = urlopen(request).read()
#print(response_body)

response_dict = json.loads(response_body.decode('utf-8'))
response_dict
items = response_dict['getPofelcddRegistSttusInfoInqire']['item']

df = pd.DataFrame(items)
df
# Out:
#   NUM     SG_ID SG_TYPECODE     HUBOID SGG_NAME SD_NAME WIW_NAME GIHO  \
# 0   1  20220601           3  100147796    서울특별시   서울특별시             1
# 1   2  20220601           3  100149260    서울특별시   서울특별시             2
# 2   3  20220601           3  100138891    서울특별시   서울특별시             3
# 3   4  20220601           3  100144119    서울특별시   서울특별시             4
# 4   5  20220601           3  100138508    서울특별시   서울특별시             5
# 5   6  20220601           3  100146196    부산광역시   부산광역시             1
# 6   7  20220601           3  100149514    부산광역시   부산광역시             2
# 7   8  20220601           3  100139837    부산광역시   부산광역시             3
# 8   9  20220601           3  100143589    대구광역시   대구광역시             1
# 9  10  20220601           3  100147274    대구광역시   대구광역시             2
#
#   GIHO_SANGSE JD_NAME  ...  BIRTHDAY AGE                 ADDR JOB_ID     JOB  \
# 0              더불어민주당  ...  19630321  59      서울특별시 송파구 거마로3길     85     변호사
# 1                국민의힘  ...  19610104  61      서울특별시 광진구 능동로4길     73  서울특별시장
# 2                 정의당  ...  19730830  48    서울특별시 강서구 강서로56나길     74   서울시의원
# 3               기본소득당  ...  19871022  34     서울특별시 은평구 통일로72길     75     정당인
# 4                 무소속  ...  19620725  59     서울특별시 강남구 광평로47길     75     정치인
# 5              더불어민주당  ...  19650716  56     부산광역시 해운대구 좌동순환로     75     정당인
# 6                국민의힘  ...  19600119  62  부산광역시 해운대구 달맞이길65번길     73  부산광역시장
# 7                 정의당  ...  19621016  59      부산광역시 영도구 해안산책길     87     회사원
# 8              더불어민주당  ...  19790425  43        대구광역시 동구 율하동로     75     정당인
# 9                국민의힘  ...  19541205  67        대구광역시 수성구 수성로     75     정치인
#
#   EDU_ID                                               EDU  \
# 0     68                                연세대학교 상경대학 경영학과 졸업
# 1    221                              고려대학교 법학대학원 졸업(법학박사)
# 2     68                                     충남대학교 물리학과 졸업
# 3     68                       이화여자대학교 사회학과 졸업(복수전공 : 여성학)
# 4     68                                     서울대학교 외교학과 졸업
# 5     68                                고려대학교 정경대학 행정학과 졸업
# 6    221                      고려대학교 대학원 사회학과 박사과정 졸업(문학박사)
# 7     65                                   부산공업고등학교 기계과 졸업
# 8    221  영국스트래스클라이드대학교 MBA(경영학 석사)졸업 (2016.9. ~ 2017.11.)
# 9     68                                고려대학교 법과대학 행정학과 졸업
#
#                         CAREER1                   CAREER2 STATUS
# 0                  (전)더불어민주당 대표               (전)국회의원(5선)     등록
# 1                (현)제38대 서울특별시장              (전)제16대 국회의원     등록
# 2                      (현)서울시의원        (전)아시아나항공 노동조합 위원장     등록
# 3        (전)2021 서울특별시장 보궐선거 후보             (현)기본소득당 상임대표     등록
# 4            (현)아리랑당 창당추진위원회 대표        (전)아리랑당 창당준비위원회 대표     등록
# 5               (전)노무현대통령 의전행정관          (전)부산광역시 시장 권한대행     등록
# 6                     (전)국회사무총장                 (현)부산광역시장     등록
# 7            (현) 정의당 부산광역시당 위원장       (전) 민주노총 부산지역본부 본부장     등록
# 8  (전)경기신용보증재단 경영기획본부장(별정직1급대우)    (전)더불어민주당 대구 동구갑 지역위원장     등록
# 9     (전) 제15,16,17,18,21대 국회의원  (전) 제20대 대통령선거 국민의힘 경선후보     등록
#
# [10 rows x 23 columns]

# %%
from urllib.request import Request,urlopen
from urllib.parse import urlencode,quote_plus
import pandas as pd
import json


skey ='EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D'
#skey ='EbwPIaTQ+n53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS+LvYw4mTX2ytwazyZbfe6SzIXv3YZKA=='

resultType = 'json'
sgId='20220601'
sgTypecode='3'

url = 'http://apis.data.go.kr/9760000/PofelcddInfoInqireService/getPofelcddRegistSttusInfoInqire'
params = f'?sgId={sgId}&sgTypecode={sgTypecode}&resultType={resultType}&serviceKey={skey}'
query = url + params
#print(query)

request = Request(query)
request.get_method = lambda:'GET'
response_body = urlopen(request).read()
#print(response_body)

response_dict = json.loads(response_body.decode('utf-8'))
response_dict
items = response_dict['getPofelcddRegistSttusInfoInqire']['item']

df = pd.DataFrame(items)
df[['SG_ID','SG_TYPECODE','HUBOID']]
# Out:
#       SG_ID SG_TYPECODE     HUBOID
# 0  20220601           3  100147796
# 1  20220601           3  100149260
# 2  20220601           3  100138891
# 3  20220601           3  100144119
# 4  20220601           3  100138508
# 5  20220601           3  100146196
# 6  20220601           3  100149514
# 7  20220601           3  100139837
# 8  20220601           3  100143589
# 9  20220601           3  100147274

# %% [markdown]
# ## 후보자정보 조건에 맞는 데이터프레임 만들기

# %%
from urllib.request import Request,urlopen
from urllib.parse import urlencode,quote_plus
import pandas as pd
import json
from bs4 import BeautifulSoup
import requests
from pandas.io.json import json_normalize

# %%
hubo_df = pd.DataFrame(columns=['SG_ID','SG_TYPECODE'])
hubo_df
# Out:
# Empty DataFrame
# Columns: [SG_ID, SG_TYPECODE]
# Index: []

# %%
sgIds = [20210407,20220309,20220601]
sgTypecodes = [2,3,4,5,6,7,8,9]

for sgId in sgIds:
    for sgTypecode in sgTypecodes:
            skey = 'EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D'
            resultType = 'json'
            
            url = 'http://apis.data.go.kr/9760000/PofelcddInfoInqireService/getPofelcddRegistSttusInfoInqire'
            params = '?sgId='+str(sgId)+'&sgTypecode='+str(sgTypecode)+'&resultType='+resultType+'&serviceKey='+skey
            query = url + params
            print(query)
            
            request = Request(query)
            request.get_method = lambda:'GET'
            
            
            response_body = urlopen(request).read()
#             print(type(response_body))
            rb_decode = response_body.decode('utf-8')
            print(type(rb_decode))
            print(rb_decode)

#             response_dict = json.loads(rb_decode)
            # rb_decode 가 jason 형식이 아니라 오류 : 데이터가 없는 경우 파싱 안됨
            try:
                response_dict = json.loads(rb_decode)
            except:
                print(rb_decode)
                continue
                
            #print(response_dict)

#             items = response_dict['getPofelcddRegistSttusInfoInqire']['item']

#             df = pd.DataFrame(items)   
#             df = json_normalize(body)
#             hubo_df = hubo_df.append(df,sort=False)

# hubo_df
# Out:
# http://apis.data.go.kr/9760000/PofelcddInfoInqireService/getPofelcddRegistSttusInfoInqire?sgId=20210407&sgTypecode=2&resultType=json&serviceKey=EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D
# <class 'str'>
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <result>
#     <code>INFO-03</code>
#     <message>데이터가 정보가 없습니다. 활용문서를 확인해 주시기 바랍니다.</message>
# </result>
#
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <result>
#     <code>INFO-03</code>
#     <message>데이터가 정보가 없습니다. 활용문서를 확인해 주시기 바랍니다.</message>
# </result>
#
# http://apis.data.go.kr/9760000/PofelcddInfoInqireService/getPofelcddRegistSttusInfoInqire?sgId=20210407&sgTypecode=3&resultType=json&serviceKey=EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D
# <class 'str'>
# {"getPofelcddRegistSttusInfoInqire":{"header":{"code":"INFO-00","message":"NORMAL SERVICE"},"item":[{"NUM":"1","SG_ID":"20210407","SG_TYPECODE":"3","HUBOID":"100138295","SGG_NAME":"서울특별시","SD_NAME":"서울특별시","WIW_NAME":"","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"박영선","HANJA_NAME":"朴映宣","GENDER":"여","BIRTHDAY":"19600122","AGE":"61","ADDR":"서울특별시 서대문구 연희로27나길","JOB_ID":"75","JOB":"정당인","EDU_ID":"221","EDU":"서강대학교 언론대학원 졸업 (문학석사)","CAREER1":"(전) 중소벤처기업부 장관","CAREER2":"(전) 17대,18대,19대,20대 국회의원","STATUS":"등록"},{"NUM":"2","SG_ID":"20210407","SG_TYPECODE":"3","HUBOID":"100138272","SGG_NAME":"서울특별시","SD_NAME":"서울특별시","WIW_NAME":"","GIHO":"2","GIHO_SANGSE":"","JD_NAME":"국민의힘","NAME":"오세훈","HANJA_NAME":"吳世勳","GENDER":"남","BIRTHDAY":"19610104","AGE":"60","ADDR":"서울특별시 광진구 능동로4길","JOB_ID":"85","JOB":"변호사","EDU_ID":"221","EDU":"고려대학교 법학대학원 졸업(법학박사)","CAREER1":"(전) 제33, 34대 서울특별시장","CAREER2":"(전) 16대 국회의원","STATUS":"등록"},{"NUM":"3","SG_ID":"20210407","SG_TYPECODE":"3","HUBOID":"100138291","SGG_NAME":"서울특별시","SD_NAME":"서울특별시","WIW_NAME":"","GIHO":"4","GIHO_SANGSE":"","JD_NAME":"국민의당","NAME":"안철수","HANJA_NAME":"安哲秀","GENDER":"남","BIRTHDAY":"19620122","AGE":"59","ADDR":"서울특별시 노원구 동일로242나길","JOB_ID":"75","JOB":"정치인","EDU_ID":"221","EDU":"서울대학교 대학원 의학박사","CAREER1":"(전)제19대, 제20대 국회의원","CAREER2":"(현)국민의당 대표","STATUS":"사퇴"},{"NUM":"4","SG_ID":"20210407","SG_TYPECODE":"3","HUBOID":"100138218","SGG_NAME":"서울특별시","SD_NAME":"서울특별시","WIW_NAME":"","GIHO":"6","GIHO_SANGSE":"","JD_NAME":"기본소득당","NAME":"신지혜","HANJA_NAME":"申智惠","GENDER":"여","BIRTHDAY":"19871022","AGE":"33","ADDR":"서울특별시 은평구 통일로72길","JOB_ID":"75","JOB":"정당인","EDU_ID":"68","EDU":"이화여자대학교 사회학과 졸업(복수전공 : 여성학)","CAREER1":"(현)기본소득당 상임대표","CAREER2":"(전)포이동 인연공부방 교사","STATUS":"등록"},{"NUM":"5","SG_ID":"20210407","SG_TYPECODE":"3","HUBOID":"100138226","SGG_NAME":"서울특별시","SD_NAME":"서울특별시","WIW_NAME":"","GIHO":"7","GIHO_SANGSE":"","JD_NAME":"국가혁명당","NAME":"허경영","HANJA_NAME":"許京寧","GENDER":"남","BIRTHDAY":"19470713","AGE":"73","ADDR":"서울특별시 종로구 북촌로5나길","JOB_ID":"225","JOB":"강연업","EDU_ID":"68","EDU":"한국방송통신대학교 법학과 법학사","CAREER1":"(전)15, 17대 대통령 후보 출마","CAREER2":"(현)국가혁명당 명예대표","STATUS":"등록"},{"NUM":"6","SG_ID":"20210407","SG_TYPECODE":"3","HUBOID":"100138327","SGG_NAME":"서울특별시","SD_NAME":"서울특별시","WIW_NAME":"","GIHO":"8","GIHO_SANGSE":"","JD_NAME":"미래당","NAME":"오태양","HANJA_NAME":"吳太陽","GENDER":"남","BIRTHDAY":"19751026","AGE":"45","ADDR":"서울특별시 광진구 뚝섬로54길","JOB_ID":"75","JOB":"정당인","EDU_ID":"221","EDU":"한림국제대학원대학교 정치외교학 석사","CAREER1":"(현) 미래당 대표","CAREER2":"(전) 청년당 사무총장","STATUS":"등록"},{"NUM":"7","SG_ID":"20210407","SG_TYPECODE":"3","HUBOID":"100138336","SGG_NAME":"서울특별시","SD_NAME":"서울특별시","WIW_NAME":"","GIHO":"9","GIHO_SANGSE":"","JD_NAME":"민생당","NAME":"이수봉","HANJA_NAME":"李守峯","GENDER":"남","BIRTHDAY":"19610623","AGE":"59","ADDR":"서울특별시 영등포구 도신로","JOB_ID":"75","JOB":"정당인","EDU_ID":"221","EDU":"서강대학교 대학원 경제학 석사","CAREER1":"(현)민생당 비상대책위원장","CAREER2":"(전)전국민주노동조합총연맹 정책연구원 원장","STATUS":"등록"},{"NUM":"8","SG_ID":"20210407","SG_TYPECODE":"3","HUBOID":"100138235","SGG_NAME":"서울특별시","SD_NAME":"서울특별시","WIW_NAME":"","GIHO":"10","GIHO_SANGSE":"","JD_NAME":"신자유민주연합","NAME":"배영규","HANJA_NAME":"裵永奎","GENDER":"남","BIRTHDAY":"19610215","AGE":"60","ADDR":"서울특별시 종로구 보문로","JOB_ID":"225","JOB":"건축·금융·보험 컨설턴트","EDU_ID":"221","EDU":"서울사회복지대학원대학교 사회복지학 석사","CAREER1":"(전)삼부토건개발(주)대표이사","CAREER2":"(현)삼성생명(주)법무컨설턴트","STATUS":"등록"},{"NUM":"9","SG_ID":"20210407","SG_TYPECODE":"3","HUBOID":"100138321","SGG_NAME":"서울특별시","SD_NAME":"서울특별시","WIW_NAME":"","GIHO":"11","GIHO_SANGSE":"","JD_NAME":"여성의당","NAME":"김진아","HANJA_NAME":"金珍芽","GENDER":"여","BIRTHDAY":"19750801","AGE":"45","ADDR":"서울특별시 용산구 녹사평대로26나길","JOB_ID":"75","JOB":"정당인","EDU_ID":"68","EDU":"홍익대학교 시각디자인과 졸업","CAREER1":"(전) 이노션월드와이드 크리에이티브 디렉터","CAREER2":"(현) 책 '나는 내 파이를 구할 뿐 인류를 구하러 온 게 아니라고' 저자","STATUS":"등록"},{"NUM":"10","SG_ID":"20210407","SG_TYPECODE":"3","HUBOID":"100138267","SGG_NAME":"서울특별시","SD_NAME":"서울특별시","WIW_NAME":"","GIHO":"12","GIHO_SANGSE":"","JD_NAME": ...
# http://apis.data.go.kr/9760000/PofelcddInfoInqireService/getPofelcddRegistSttusInfoInqire?sgId=20210407&sgTypecode=4&resultType=json&serviceKey=EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D
# <class 'str'>
# {"getPofelcddRegistSttusInfoInqire":{"header":{"code":"INFO-00","message":"NORMAL SERVICE"},"item":[{"NUM":"1","SG_ID":"20210407","SG_TYPECODE":"4","HUBOID":"100138299","SGG_NAME":"남구","SD_NAME":"울산광역시","WIW_NAME":"남구","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"김석겸","HANJA_NAME":"金錫謙","GENDER":"남","BIRTHDAY":"19610514","AGE":"59","ADDR":"울산광역시 남구 야음로","JOB_ID":"75","JOB":"정당인","EDU_ID":"221","EDU":"울산대학교 정책대학원 졸업 (행정학석사, 도시개발전공)","CAREER1":"(전)울산광역시 남구청장 권한대행 부구청장","CAREER2":"(현)더불어민주당 정책위원회 부의장","STATUS":"등록"},{"NUM":"2","SG_ID":"20210407","SG_TYPECODE":"4","HUBOID":"100138285","SGG_NAME":"남구","SD_NAME":"울산광역시","WIW_NAME":"남구","GIHO":"2","GIHO_SANGSE":"","JD_NAME":"국민의힘","NAME":"서동욱","HANJA_NAME":"徐東旭","GENDER":"남","BIRTHDAY":"19630124","AGE":"58","ADDR":"울산광역시 남구 월평로","JOB_ID":"75","JOB":"정당인","EDU_ID":"221","EDU":"동국대학교 사회과학대학원 졸업 (행정학석사)","CAREER1":"(전)울산광역시 남구청장","CAREER2":"(전)제5대 울산광역시의회의장","STATUS":"등록"},{"NUM":"3","SG_ID":"20210407","SG_TYPECODE":"4","HUBOID":"100138240","SGG_NAME":"남구","SD_NAME":"울산광역시","WIW_NAME":"남구","GIHO":"6","GIHO_SANGSE":"","JD_NAME":"진보당","NAME":"김진석","HANJA_NAME":"金眞奭","GENDER":"남","BIRTHDAY":"19630920","AGE":"57","ADDR":"울산광역시 남구 야음로26번길","JOB_ID":"75","JOB":"정당인","EDU_ID":"68","EDU":"울산대학교 전자및전산기공학과 졸업 공학사","CAREER1":"(전)울산광역시 제2대 남구의회 의원","CAREER2":"(현)울산소상공인포럼 고문","STATUS":"등록"},{"NUM":"4","SG_ID":"20210407","SG_TYPECODE":"4","HUBOID":"100138278","SGG_NAME":"의령군","SD_NAME":"경상남도","WIW_NAME":"의령군","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"김충규","HANJA_NAME":"金忠圭","GENDER":"남","BIRTHDAY":"19550216","AGE":"66","ADDR":"경상남도 의령군 의령읍 의병로14길","JOB_ID":"75","JOB":"더불어민주당 정책위원회 부의장","EDU_ID":"221","EDU":"부산대학교 행정대학원 행정학과 졸업(행정학 석사)","CAREER1":"(전)동해.남해지방해양경찰청장","CAREER2":"(현)더불어민주당 경상남도당 부위원장","STATUS":"등록"},{"NUM":"5","SG_ID":"20210407","SG_TYPECODE":"4","HUBOID":"100138274","SGG_NAME":"의령군","SD_NAME":"경상남도","WIW_NAME":"의령군","GIHO":"2","GIHO_SANGSE":"","JD_NAME":"국민의힘","NAME":"오태완","HANJA_NAME":"吳泰完","GENDER":"남","BIRTHDAY":"19660307","AGE":"55","ADDR":"경상남도 의령군 의령읍 의병로25길","JOB_ID":"75","JOB":"국민의힘 중앙위 지방행정 특보단장","EDU_ID":"221","EDU":"경남대학교 대학원 경영학과 졸업(경영학박사)","CAREER1":"(전)경남도청 정무특보(1급상당)","CAREER2":"(전)경상남도 정책단장(2급상당)","STATUS":"등록"},{"NUM":"6","SG_ID":"20210407","SG_TYPECODE":"4","HUBOID":"100138304","SGG_NAME":"의령군","SD_NAME":"경상남도","WIW_NAME":"의령군","GIHO":"6","GIHO_SANGSE":"","JD_NAME":"무소속","NAME":"오용","HANJA_NAME":"吳龍","GENDER":"남","BIRTHDAY":"19560329","AGE":"65","ADDR":"경상남도 의령군 의령읍 남산로","JOB_ID":"75","JOB":"정치인","EDU_ID":"765","EDU":"마산대학(현 마산대학교) 전통약재개발과 졸업","CAREER1":"(전)의령군의회 의장","CAREER2":"(전)의령군생활체육회 사무국장","STATUS":"등록"},{"NUM":"7","SG_ID":"20210407","SG_TYPECODE":"4","HUBOID":"100138292","SGG_NAME":"의령군","SD_NAME":"경상남도","WIW_NAME":"의령군","GIHO":"7","GIHO_SANGSE":"","JD_NAME":"무소속","NAME":"김창환","HANJA_NAME":"金昌煥","GENDER":"남","BIRTHDAY":"19730513","AGE":"47","ADDR":"경상남도 의령군 대의면 한티로3길","JOB_ID":"85","JOB":"법무법인 창 대표변호사","EDU_ID":"68","EDU":"고려대학교 법과대학 법학과 졸업","CAREER1":"(전)서울서부지검 검사","CAREER2":"(전)의령군 고문변호사","STATUS":"등록"}],"rows":null,"numOfRows":10,"pageNo":1,"totalCount":7}}
# http://apis.data.go.kr/9760000/PofelcddInfoInqireService/getPofelcddRegistSttusInfoInqire?sgId=20210407&sgTypecode=5&resultType=json&serviceKey=EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D
# <class 'str'>
# {"getPofelcddRegistSttusInfoInqire":{"header":{"code":"INFO-00","message":"NORMAL SERVICE"},"item":[{"NUM":"1","SG_ID":"20210407","SG_TYPECODE":"5","HUBOID":"100138343","SGG_NAME":"강북구제1선거구","SD_NAME":"서울특별시","WIW_NAME":"강북구","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"김승식","HANJA_NAME":"金承植","GENDER":"남","BIRTHDAY":"19570520","AGE":"63","ADDR":"서울특별시 강북구 도봉로","JOB_ID":"75","JOB":"정당인","EDU_ID":"221","EDU":"한성대학교 대학원 행정학과 졸업(행정학 박사)","CAREER1":"(현)더불어민주당 서울시당 대변인","CAREER2":"(전)한성대학교 사회과학대학 행정학과 겸임교수","STATUS":"등록"},{"NUM":"2","SG_ID":"20210407","SG_TYPECODE":"5","HUBOID":"100138234","SGG_NAME":"강북구제1선거구","SD_NAME":"서울특별시","WIW_NAME":"강북구","GIHO":"2","GIHO_SANGSE":"","JD_NAME":"국민의힘","NAME":"이종환","HANJA_NAME":"李鍾桓","GENDER":"남","BIRTHDAY":"19561211","AGE":"64","ADDR":"서울특별시 강북구 한천로140길","JOB_ID":"77","JOB":"향촌숯불구이전문점 대표","EDU_ID":"65","EDU":"청주상업고등학교(현 청주대성고등학교) 졸업","CAREER1":"(전)한국외식업중앙회 강북구지회 지회장","CAREER2":"(현)향촌숯불구이전문점 대표","STATUS":"등록"},{"NUM":"3","SG_ID":"20210407","SG_TYPECODE":"5","HUBOID":"100138243","SGG_NAME":"구리시제1선거구","SD_NAME":"경기도","WIW_NAME":"구리시","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"신동화","HANJA_NAME":"申東和","GENDER":"남","BIRTHDAY":"19661228","AGE":"54","ADDR":"경기도 구리시 동구릉로","JOB_ID":"75","JOB":"정당인","EDU_ID":"221","EDU":"서울시립대학교 도시과학대학원 졸업(도시행정학석사)","CAREER1":"(전)구리시의회 의장","CAREER2":"(전)윤호중 국회의원 정책보좌관","STATUS":"등록"},{"NUM":"4","SG_ID":"20210407","SG_TYPECODE":"5","HUBOID":"100138252","SGG_NAME":"구리시제1선거구","SD_NAME":"경기도","WIW_NAME":"구리시","GIHO":"2","GIHO_SANGSE":"","JD_NAME":"국민의힘","NAME":"백현종","HANJA_NAME":"白鉉宗","GENDER":"남","BIRTHDAY":"19651014","AGE":"55","ADDR":"경기도 구리시 경춘로","JOB_ID":"75","JOB":"정당인","EDU_ID":"68","EDU":"한국항공대학교 항공기계공학과 졸업","CAREER1":"(전)국민의당 구리시장 후보","CAREER2":"(현)국민의힘 경기도당 민생경제활성화 특별위원회 위원장","STATUS":"등록"},{"NUM":"5","SG_ID":"20210407","SG_TYPECODE":"5","HUBOID":"100138254","SGG_NAME":"보은군선거구","SD_NAME":"충청북도","WIW_NAME":"보은군","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"김기준","HANJA_NAME":"金基俊","GENDER":"남","BIRTHDAY":"19660515","AGE":"54","ADDR":"충청북도 보은군 보은읍 월송로","JOB_ID":"225","JOB":"시인","EDU_ID":"68","EDU":"청주대학교 예술대학 연극영화학과 졸업","CAREER1":"(전)보은군수 후보(2006년 전국동시지방선거)","CAREER2":"(전)뉴스1 세종충북 취재국장","STATUS":"등록"},{"NUM":"6","SG_ID":"20210407","SG_TYPECODE":"5","HUBOID":"100138266","SGG_NAME":"보은군선거구","SD_NAME":"충청북도","WIW_NAME":"보은군","GIHO":"2","GIHO_SANGSE":"","JD_NAME":"국민의힘","NAME":"원갑희","HANJA_NAME":"元甲喜","GENDER":"남","BIRTHDAY":"19640617","AGE":"56","ADDR":"충청북도 보은군 마로면 관기송현로","JOB_ID":"76","JOB":"축산업","EDU_ID":"67","EDU":"한국방송통신대학교 영어영문학과 재학중","CAREER1":"(전)제7대 보은군의회의원","CAREER2":"(전)마로면새마을협의회회장","STATUS":"등록"},{"NUM":"7","SG_ID":"20210407","SG_TYPECODE":"5","HUBOID":"100138251","SGG_NAME":"보은군선거구","SD_NAME":"충청북도","WIW_NAME":"보은군","GIHO":"6","GIHO_SANGSE":"","JD_NAME":"무소속","NAME":"박경숙","HANJA_NAME":"朴瓊淑","GENDER":"여","BIRTHDAY":"19610715","AGE":"59","ADDR":"충청북도 보은군 보은읍 삼산로1길","JOB_ID":"224","JOB":"무직","EDU_ID":"68","EDU":"청주대학교 교육학부 지리교육과 졸업","CAREER1":"(전)제7대 보은군의회의원","CAREER2":"(전)제7대 보은군의회 전반기 부의장","STATUS":"등록"},{"NUM":"8","SG_ID":"20210407","SG_TYPECODE":"5","HUBOID":"100138346","SGG_NAME":"순천시제1선거구","SD_NAME":"전라남도","WIW_NAME":"순천시","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"한춘옥","HANJA_NAME":"韓春玉","GENDER":"여","BIRTHDAY":"19641112","AGE":"56","ADDR":"전라남도 순천시 봉화1길","JOB_ID":"83","JOB":"순천농협 장천지점장","EDU_ID":"65","EDU":"순천여자상업고등학교 (현 순천청암고등학교) 졸업","CAREER1":"(현)순천농협 장천지점장","CAREER2":"(현)순천시배구협회 부회장","STATUS":"등록"},{"NUM":"9","SG_ID":"20210407","SG_TYPECODE":"5","HUBOID":"100138290","SGG_NAME":"순천시제1선거구","SD_NAME":"전라남도","WIW_NAME":"순천시","GIHO":"6","GIHO_SANGSE":"","JD_NAME":"무소속","NAME":"주윤식","HANJA_NAME":"朱允植","GENDER":"남","BIRTHDAY":"19601023","AGE":"60","ADDR":"전라남도 순천시 신풍길","JOB_ID":"225","JOB":"여수오션리조트(주) 대표이사","EDU_ID":"221","EDU":"동국대학교 경찰사법대학원 경찰사법학과 경찰학전공(경찰학석사)","CAREER1":"(전)순천시의회 부의장","CAREER2":"(전)농림수산식품교육문화정보원 비상임이사","STATUS":"등록"},{"NUM":"10","SG_ID":"20210407","SG_TYPECODE":"5","HUBOID":"100138246","SGG_NAM ...
# http://apis.data.go.kr/9760000/PofelcddInfoInqireService/getPofelcddRegistSttusInfoInqire?sgId=20210407&sgTypecode=6&resultType=json&serviceKey=EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D
# <class 'str'>
# {"getPofelcddRegistSttusInfoInqire":{"header":{"code":"INFO-00","message":"NORMAL SERVICE"},"item":[{"NUM":"1","SG_ID":"20210407","SG_TYPECODE":"6","HUBOID":"100138340","SGG_NAME":"영등포구바선거구","SD_NAME":"서울특별시","WIW_NAME":"영등포구","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"양송이","HANJA_NAME":"梁松伊","GENDER":"여","BIRTHDAY":"19760816","AGE":"44","ADDR":"서울특별시 영등포구 도림로91길","JOB_ID":"225","JOB":"복지기관 단체인","EDU_ID":"221","EDU":"건국대학교 일반대학원 교육학박사","CAREER1":"(현)더불어민주당 서울시당 대변인","CAREER2":"(전)영등포구 장학재단 사무국장","STATUS":"등록"},{"NUM":"2","SG_ID":"20210407","SG_TYPECODE":"6","HUBOID":"100138245","SGG_NAME":"영등포구바선거구","SD_NAME":"서울특별시","WIW_NAME":"영등포구","GIHO":"2","GIHO_SANGSE":"","JD_NAME":"국민의힘","NAME":"차인영","HANJA_NAME":"車仁永","GENDER":"여","BIRTHDAY":"19750420","AGE":"45","ADDR":"서울특별시 영등포구 신풍로","JOB_ID":"75","JOB":"정당인","EDU_ID":"221","EDU":"동국대학교 대학원 식품공학과 졸업(공학석사)","CAREER1":"(현)신길중학교유치위원회 위원장","CAREER2":"(전)제12기 서울대방초등학교 운영위원회 운영위원장","STATUS":"등록"},{"NUM":"3","SG_ID":"20210407","SG_TYPECODE":"6","HUBOID":"100138341","SGG_NAME":"송파구라선거구","SD_NAME":"서울특별시","WIW_NAME":"송파구","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"배신정","HANJA_NAME":"裵晨井","GENDER":"여","BIRTHDAY":"19750107","AGE":"46","ADDR":"서울특별시 송파구 올림픽로","JOB_ID":"225","JOB":"정당인","EDU_ID":"68","EDU":"숙명여자대학교 법학과 학사졸업","CAREER1":"(현)더불어민주당 정책위 부의장","CAREER2":"(전)최재성 국회의원 비서관","STATUS":"등록"},{"NUM":"4","SG_ID":"20210407","SG_TYPECODE":"6","HUBOID":"100138334","SGG_NAME":"송파구라선거구","SD_NAME":"서울특별시","WIW_NAME":"송파구","GIHO":"2","GIHO_SANGSE":"","JD_NAME":"국민의힘","NAME":"김순애","HANJA_NAME":"金順愛","GENDER":"여","BIRTHDAY":"19480711","AGE":"72","ADDR":"서울특별시 송파구 올림픽로4길","JOB_ID":"225","JOB":"정당인","EDU_ID":"65","EDU":"서울 무학여자고등학교 졸업","CAREER1":"(전)송파구의회의원(6~7대)","CAREER2":"(전)서울시공무원","STATUS":"등록"},{"NUM":"5","SG_ID":"20210407","SG_TYPECODE":"6","HUBOID":"100138330","SGG_NAME":"송파구라선거구","SD_NAME":"서울특별시","WIW_NAME":"송파구","GIHO":"6","GIHO_SANGSE":"","JD_NAME":"미래당","NAME":"최지선","HANJA_NAME":"崔志先","GENDER":"여","BIRTHDAY":"19900225","AGE":"31","ADDR":"서울특별시 송파구 백제고분로18길","JOB_ID":"225","JOB":"정당인","EDU_ID":"68","EDU":"미국 노트르담 대학교 문학사(정치학과) 졸업(2008.08.~2012.05.)","CAREER1":"(전)한국직업능력개발원 위촉연구원","CAREER2":"(현)미래당 기후행동팀장","STATUS":"등록"},{"NUM":"6","SG_ID":"20210407","SG_TYPECODE":"6","HUBOID":"100138355","SGG_NAME":"울주군나선거구","SD_NAME":"울산광역시","WIW_NAME":"울주군","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"김기락","HANJA_NAME":"金基洛","GENDER":"남","BIRTHDAY":"19670418","AGE":"53","ADDR":"울산광역시 울주군 청량읍 양동2길","JOB_ID":"75","JOB":"정당인","EDU_ID":"65","EDU":"고등학교졸업학력 검정고시 합격","CAREER1":"(전)청량읍 체육회장","CAREER2":"(현)민주평화통일자문회의 자문위원","STATUS":"등록"},{"NUM":"7","SG_ID":"20210407","SG_TYPECODE":"6","HUBOID":"100138329","SGG_NAME":"울주군나선거구","SD_NAME":"울산광역시","WIW_NAME":"울주군","GIHO":"2","GIHO_SANGSE":"","JD_NAME":"국민의힘","NAME":"박기홍","HANJA_NAME":"朴基弘","GENDER":"남","BIRTHDAY":"19660809","AGE":"54","ADDR":"울산광역시 울주군 범서읍 대리로","JOB_ID":"225","JOB":"자영업","EDU_ID":"68","EDU":"울산대학교 체육학과 졸업","CAREER1":"(현)범서읍체육회회장","CAREER2":"(전)민주평화통일자문회의 울주군협의회 부회장","STATUS":"등록"},{"NUM":"8","SG_ID":"20210407","SG_TYPECODE":"6","HUBOID":"100138255","SGG_NAME":"파주시가선거구","SD_NAME":"경기도","WIW_NAME":"파주시","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"손성익","HANJA_NAME":"孫星益","GENDER":"남","BIRTHDAY":"19870522","AGE":"33","ADDR":"경기도 파주시 심학산로","JOB_ID":"87","JOB":"회사원","EDU_ID":"68","EDU":"학점인정 등에 관한 법률에 따른 경영학사 학위취득","CAREER1":"(현)더불어민주당 정책위원회 부의장","CAREER2":"(현)더불어민주당 전국청년당 대변인","STATUS":"등록"},{"NUM":"9","SG_ID":"20210407","SG_TYPECODE":"6","HUBOID":"100138318","SGG_NAME":"파주시가선거구","SD_NAME":"경기도","WIW_NAME":"파주시","GIHO":"2","GIHO_SANGSE":"","JD_NAME":"국민의힘","NAME":"박수연","HANJA_NAME":"朴秀娟","GENDER":"여","BIRTHDAY":"19750325","AGE":"46","ADDR":"경기도 파주시 가온로","JOB_ID":"75","JOB":"정당인","EDU_ID":"68","EDU":"이화여자대학교 정치외교학과 졸업","CAREER1":"(현)제8기 파주시민기자","CAREER2":"(전)고양신문 기자","STATUS":"등록"},{"NUM":"10","SG_ID":"20210407","SG_TYPECODE":"6","HUBOID":"100138249","SGG_NAME":"파주시가선거구","SD_NAME":"경기도","WIW_NAME":"파주시","GIHO":" ...
# http://apis.data.go.kr/9760000/PofelcddInfoInqireService/getPofelcddRegistSttusInfoInqire?sgId=20210407&sgTypecode=7&resultType=json&serviceKey=EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D
# <class 'str'>
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <result>
#     <code>INFO-03</code>
#     <message>데이터가 정보가 없습니다. 활용문서를 확인해 주시기 바랍니다.</message>
# </result>
#
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <result>
#     <code>INFO-03</code>
#     <message>데이터가 정보가 없습니다. 활용문서를 확인해 주시기 바랍니다.</message>
# </result>
#
# http://apis.data.go.kr/9760000/PofelcddInfoInqireService/getPofelcddRegistSttusInfoInqire?sgId=20210407&sgTypecode=8&resultType=json&serviceKey=EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D
# <class 'str'>
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <result>
#     <code>INFO-03</code>
#     <message>데이터가 정보가 없습니다. 활용문서를 확인해 주시기 바랍니다.</message>
# </result>
#
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <result>
#     <code>INFO-03</code>
#     <message>데이터가 정보가 없습니다. 활용문서를 확인해 주시기 바랍니다.</message>
# </result>
#
# http://apis.data.go.kr/9760000/PofelcddInfoInqireService/getPofelcddRegistSttusInfoInqire?sgId=20210407&sgTypecode=9&resultType=json&serviceKey=EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D
# <class 'str'>
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <result>
#     <code>INFO-03</code>
#     <message>데이터가 정보가 없습니다. 활용문서를 확인해 주시기 바랍니다.</message>
# </result>
#
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <result>
#     <code>INFO-03</code>
#     <message>데이터가 정보가 없습니다. 활용문서를 확인해 주시기 바랍니다.</message>
# </result>
#
# http://apis.data.go.kr/9760000/PofelcddInfoInqireService/getPofelcddRegistSttusInfoInqire?sgId=20220309&sgTypecode=2&resultType=json&serviceKey=EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D
# <class 'str'>
# {"getPofelcddRegistSttusInfoInqire":{"header":{"code":"INFO-00","message":"NORMAL SERVICE"},"item":[{"NUM":"1","SG_ID":"20220309","SG_TYPECODE":"2","HUBOID":"100138535","SGG_NAME":"종로구","SD_NAME":"서울특별시","WIW_NAME":"종로구","GIHO":"2","GIHO_SANGSE":"","JD_NAME":"국민의힘","NAME":"최재형","HANJA_NAME":"崔在亨","GENDER":"남","BIRTHDAY":"19560902","AGE":"65","ADDR":"서울특별시 양천구 목동중앙로7길","JOB_ID":"75","JOB":"정당인","EDU_ID":"68","EDU":"서울대학교 법학과 졸업","CAREER1":"(전)감사원장","CAREER2":"(전)사법연수원장","STATUS":"등록"},{"NUM":"2","SG_ID":"20220309","SG_TYPECODE":"2","HUBOID":"100138425","SGG_NAME":"종로구","SD_NAME":"서울특별시","WIW_NAME":"종로구","GIHO":"3","GIHO_SANGSE":"","JD_NAME":"정의당","NAME":"배복주","HANJA_NAME":"裵福珠","GENDER":"여","BIRTHDAY":"19710715","AGE":"50","ADDR":"서울특별시 종로구 창경궁로35길","JOB_ID":"75","JOB":"정당인","EDU_ID":"69","EDU":"서울시립대학교 도시과학대학원 사회복지학과 석사 수료","CAREER1":"(현) 정의당 부대표","CAREER2":"(전) 전국성폭력상담소협의회 상임대표","STATUS":"등록"},{"NUM":"3","SG_ID":"20220309","SG_TYPECODE":"2","HUBOID":"100138482","SGG_NAME":"종로구","SD_NAME":"서울특별시","WIW_NAME":"종로구","GIHO":"5","GIHO_SANGSE":"","JD_NAME":"시대전환","NAME":"김도연","HANJA_NAME":"金度延","GENDER":"여","BIRTHDAY":"19800730","AGE":"41","ADDR":"서울특별시 종로구 계동길","JOB_ID":"225","JOB":"(주)인사이드99 대표이사","EDU_ID":"220","EDU":"국민대학교 글로벌창업벤처대학원 창업학 석사","CAREER1":"(현)시대전환 상임대표당원","CAREER2":"(현)창업전문 컨설턴트","STATUS":"등록"},{"NUM":"4","SG_ID":"20220309","SG_TYPECODE":"2","HUBOID":"100138408","SGG_NAME":"종로구","SD_NAME":"서울특별시","WIW_NAME":"종로구","GIHO":"6","GIHO_SANGSE":"","JD_NAME":"국민혁명당","NAME":"구본철","HANJA_NAME":"具本喆","GENDER":"남","BIRTHDAY":"19590124","AGE":"63","ADDR":"인천광역시 부평구 수변로","JOB_ID":"75","JOB":"정당인","EDU_ID":"221","EDU":"사우스플로리다대학교 대학원 졸업(전기공학박사)('89.08~'94.05)","CAREER1":"(전)제18대 국회의원 역임","CAREER2":"(현)원자력살리기국민행동 상임대표","STATUS":"등록"},{"NUM":"5","SG_ID":"20220309","SG_TYPECODE":"2","HUBOID":"100138545","SGG_NAME":"종로구","SD_NAME":"서울특별시","WIW_NAME":"종로구","GIHO":"7","GIHO_SANGSE":"","JD_NAME":"독도한국당","NAME":"김두환","HANJA_NAME":"金斗煥","GENDER":"남","BIRTHDAY":"19460520","AGE":"75","ADDR":"서울특별시 종로구 성균관로10길","JOB_ID":"225","JOB":"대학생","EDU_ID":"68","EDU":"한국방송통신대학교 법학과 졸업","CAREER1":"(전) 화물트럭 11톤 운수업 10년","CAREER2":"(전)사단법인 경산애육원 이사 11년","STATUS":"등록"},{"NUM":"6","SG_ID":"20220309","SG_TYPECODE":"2","HUBOID":"100138536","SGG_NAME":"종로구","SD_NAME":"서울특별시","WIW_NAME":"종로구","GIHO":"8","GIHO_SANGSE":"","JD_NAME":"새로운물결","NAME":"송문희","HANJA_NAME":"宋文熙","GENDER":"여","BIRTHDAY":"19680309","AGE":"54","ADDR":"서울특별시 서초구 방배로2길","JOB_ID":"82","JOB":"정치평론가","EDU_ID":"221","EDU":"고려대학교 대학원 정치외교학과 졸업(정치학박사)","CAREER1":"(전)고려대학교 연구교수","CAREER2":"(현)새로운물결 김동연 대통령후보 대변인","STATUS":"등록"},{"NUM":"7","SG_ID":"20220309","SG_TYPECODE":"2","HUBOID":"100138534","SGG_NAME":"종로구","SD_NAME":"서울특별시","WIW_NAME":"종로구","GIHO":"9","GIHO_SANGSE":"","JD_NAME":"통일한국당","NAME":"윤대관","HANJA_NAME":"尹大觀","GENDER":"남","BIRTHDAY":"19690112","AGE":"53","ADDR":"서울특별시 중랑구 중랑역로","JOB_ID":"225","JOB":"(주)메가메타리치 본부장","EDU_ID":"68","EDU":"한국외국어대학교 법과대학 법학과 졸업","CAREER1":"(전) (주) 위니아에셋 대표이사","CAREER2":"","STATUS":"등록"},{"NUM":"8","SG_ID":"20220309","SG_TYPECODE":"2","HUBOID":"100138522","SGG_NAME":"종로구","SD_NAME":"서울특별시","WIW_NAME":"종로구","GIHO":"10","GIHO_SANGSE":"","JD_NAME":"무소속","NAME":"서주원","HANJA_NAME":"徐柱源","GENDER":"남","BIRTHDAY":"19661110","AGE":"55","ADDR":"서울특별시 종로구 필운대로5가길","JOB_ID":"225","JOB":"방송작가","EDU_ID":"68","EDU":"성균관대학교 중어중문학과 졸업","CAREER1":"(현)노무현리더십연구소 소장","CAREER2":"(현)더불어민주당 정풍운동연대 대변인","STATUS":"등록"},{"NUM":"9","SG_ID":"20220309","SG_TYPECODE":"2","HUBOID":"100138542","SGG_NAME":"종로구","SD_NAME":"서울특별시","WIW_NAME":"종로구","GIHO":"11","GIHO_SANGSE":"","JD_NAME":"무소속","NAME":"박종구","HANJA_NAME":"朴鐘九","GENDER":"남","BIRTHDAY":"19490725","AGE":"72","ADDR":"경기도 남양주시 순화궁로","JOB_ID":"225","JOB":"민족통일운동가","EDU_ID":"68","EDU":"연세대학교 정법대학 법학과 졸업","CAREER1":"(전)한국독립당 재건위원장","CAREER2":"(현)통일광복민족회의 상임대표","STATUS":"등록"},{"NUM":"10","SG_ID":"20220309","SG_TYPECODE":"2","HUBOID":"100138537","SGG_NAME":"종로구","SD_NAME":"서울특별시","WIW_NAME":"종로구","GIHO":"12","GIHO_SANGSE":"","JD_NAME":"무소속", ...
# http://apis.data.go.kr/9760000/PofelcddInfoInqireService/getPofelcddRegistSttusInfoInqire?sgId=20220309&sgTypecode=3&resultType=json&serviceKey=EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D
# <class 'str'>
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <result>
#     <code>INFO-03</code>
#     <message>데이터가 정보가 없습니다. 활용문서를 확인해 주시기 바랍니다.</message>
# </result>
#
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <result>
#     <code>INFO-03</code>
#     <message>데이터가 정보가 없습니다. 활용문서를 확인해 주시기 바랍니다.</message>
# </result>
#
# http://apis.data.go.kr/9760000/PofelcddInfoInqireService/getPofelcddRegistSttusInfoInqire?sgId=20220309&sgTypecode=4&resultType=json&serviceKey=EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D
# <class 'str'>
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <result>
#     <code>INFO-03</code>
#     <message>데이터가 정보가 없습니다. 활용문서를 확인해 주시기 바랍니다.</message>
# </result>
#
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <result>
#     <code>INFO-03</code>
#     <message>데이터가 정보가 없습니다. 활용문서를 확인해 주시기 바랍니다.</message>
# </result>
#
# http://apis.data.go.kr/9760000/PofelcddInfoInqireService/getPofelcddRegistSttusInfoInqire?sgId=20220309&sgTypecode=5&resultType=json&serviceKey=EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D
# <class 'str'>
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <result>
#     <code>INFO-03</code>
#     <message>데이터가 정보가 없습니다. 활용문서를 확인해 주시기 바랍니다.</message>
# </result>
#
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <result>
#     <code>INFO-03</code>
#     <message>데이터가 정보가 없습니다. 활용문서를 확인해 주시기 바랍니다.</message>
# </result>
#
# http://apis.data.go.kr/9760000/PofelcddInfoInqireService/getPofelcddRegistSttusInfoInqire?sgId=20220309&sgTypecode=6&resultType=json&serviceKey=EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D
# <class 'str'>
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <result>
#     <code>INFO-03</code>
#     <message>데이터가 정보가 없습니다. 활용문서를 확인해 주시기 바랍니다.</message>
# </result>
#
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <result>
#     <code>INFO-03</code>
#     <message>데이터가 정보가 없습니다. 활용문서를 확인해 주시기 바랍니다.</message>
# </result>
#
# http://apis.data.go.kr/9760000/PofelcddInfoInqireService/getPofelcddRegistSttusInfoInqire?sgId=20220309&sgTypecode=7&resultType=json&serviceKey=EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D
# <class 'str'>
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <result>
#     <code>INFO-03</code>
#     <message>데이터가 정보가 없습니다. 활용문서를 확인해 주시기 바랍니다.</message>
# </result>
#
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <result>
#     <code>INFO-03</code>
#     <message>데이터가 정보가 없습니다. 활용문서를 확인해 주시기 바랍니다.</message>
# </result>
#
# http://apis.data.go.kr/9760000/PofelcddInfoInqireService/getPofelcddRegistSttusInfoInqire?sgId=20220309&sgTypecode=8&resultType=json&serviceKey=EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D
# <class 'str'>
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <result>
#     <code>INFO-03</code>
#     <message>데이터가 정보가 없습니다. 활용문서를 확인해 주시기 바랍니다.</message>
# </result>
#
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <result>
#     <code>INFO-03</code>
#     <message>데이터가 정보가 없습니다. 활용문서를 확인해 주시기 바랍니다.</message>
# </result>
#
# http://apis.data.go.kr/9760000/PofelcddInfoInqireService/getPofelcddRegistSttusInfoInqire?sgId=20220309&sgTypecode=9&resultType=json&serviceKey=EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D
# <class 'str'>
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <result>
#     <code>INFO-03</code>
#     <message>데이터가 정보가 없습니다. 활용문서를 확인해 주시기 바랍니다.</message>
# </result>
#
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <result>
#     <code>INFO-03</code>
#     <message>데이터가 정보가 없습니다. 활용문서를 확인해 주시기 바랍니다.</message>
# </result>
#
# http://apis.data.go.kr/9760000/PofelcddInfoInqireService/getPofelcddRegistSttusInfoInqire?sgId=20220601&sgTypecode=2&resultType=json&serviceKey=EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D
# <class 'str'>
# {"getPofelcddRegistSttusInfoInqire":{"header":{"code":"INFO-00","message":"NORMAL SERVICE"},"item":[{"NUM":"1","SG_ID":"20220601","SG_TYPECODE":"2","HUBOID":"100149874","SGG_NAME":"수성구을","SD_NAME":"대구광역시","WIW_NAME":"수성구","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"김용락","HANJA_NAME":"金龍洛","GENDER":"남","BIRTHDAY":"19590525","AGE":"63","ADDR":"대구광역시 수성구 지범로40길","JOB_ID":"75","JOB":"정당인","EDU_ID":"221","EDU":"계명대학교 대학원 문학박사","CAREER1":"(전)한국국제문화교류진흥원 원장","CAREER2":"(전)경운대학교 교수","STATUS":"등록"},{"NUM":"2","SG_ID":"20220601","SG_TYPECODE":"2","HUBOID":"100150313","SGG_NAME":"수성구을","SD_NAME":"대구광역시","WIW_NAME":"수성구","GIHO":"2","GIHO_SANGSE":"","JD_NAME":"국민의힘","NAME":"이인선","HANJA_NAME":"李仁善","GENDER":"여","BIRTHDAY":"19590502","AGE":"63","ADDR":"대구광역시 수성구 들안로","JOB_ID":"88","JOB":"대학교수","EDU_ID":"221","EDU":"영남대학교 대학원 졸업(이학박사)","CAREER1":"(전)대통령직인수위원회 지역균형발전특별위원회 위원","CAREER2":"(전)경상북도 경제부지사","STATUS":"등록"},{"NUM":"3","SG_ID":"20220601","SG_TYPECODE":"2","HUBOID":"100150092","SGG_NAME":"계양구을","SD_NAME":"인천광역시","WIW_NAME":"계양구","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"이재명","HANJA_NAME":"李在明","GENDER":"남","BIRTHDAY":"19641222","AGE":"57","ADDR":"인천광역시 계양구 계산새로65번길","JOB_ID":"225","JOB":"정당인","EDU_ID":"68","EDU":"중앙대학교 법학과 졸업","CAREER1":"(전)제20대 대통령선거 후보","CAREER2":"(전)경기도지사","STATUS":"등록"},{"NUM":"4","SG_ID":"20220601","SG_TYPECODE":"2","HUBOID":"100148344","SGG_NAME":"계양구을","SD_NAME":"인천광역시","WIW_NAME":"계양구","GIHO":"2","GIHO_SANGSE":"","JD_NAME":"국민의힘","NAME":"윤형선","HANJA_NAME":"尹炯善","GENDER":"남","BIRTHDAY":"19610410","AGE":"61","ADDR":"인천광역시 계양구 계양문화로","JOB_ID":"84","JOB":"계양속편한 내과 대표원장","EDU_ID":"221","EDU":"고려대학교 대학원 박사과정 졸업(의학박사)","CAREER1":"(전)인천광역시 의사회 회장","CAREER2":"(전)국민의힘 계양구을 당협위원장","STATUS":"등록"},{"NUM":"5","SG_ID":"20220601","SG_TYPECODE":"2","HUBOID":"100148724","SGG_NAME":"성남시분당구갑","SD_NAME":"경기도","WIW_NAME":"성남시분당구","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"김병관","HANJA_NAME":"金炳官","GENDER":"남","BIRTHDAY":"19730115","AGE":"49","ADDR":"경기도 성남시 분당구 산운로","JOB_ID":"75","JOB":"정당인","EDU_ID":"221","EDU":"한국과학기술원(KAIST) 경영공학전공 졸업 (공학석사)","CAREER1":"(전) 제20대 국회의원","CAREER2":"(전) 국회의장 비서실장","STATUS":"등록"},{"NUM":"6","SG_ID":"20220601","SG_TYPECODE":"2","HUBOID":"100148608","SGG_NAME":"성남시분당구갑","SD_NAME":"경기도","WIW_NAME":"성남시분당구","GIHO":"2","GIHO_SANGSE":"","JD_NAME":"국민의힘","NAME":"안철수","HANJA_NAME":"安哲秀","GENDER":"남","BIRTHDAY":"19620122","AGE":"60","ADDR":"경기도 성남시 분당구 대왕판교로606번길","JOB_ID":"75","JOB":"정치인","EDU_ID":"221","EDU":"서울대학교 대학원 졸업 (의학박사)","CAREER1":"(전) 대통령직인수위원회 위원장","CAREER2":"(전) 19대, 20대 국회의원","STATUS":"등록"},{"NUM":"7","SG_ID":"20220601","SG_TYPECODE":"2","HUBOID":"100148313","SGG_NAME":"원주시갑","SD_NAME":"강원도","WIW_NAME":"원주시","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"원창묵","HANJA_NAME":"元昌默","GENDER":"남","BIRTHDAY":"19601210","AGE":"61","ADDR":"강원도 원주시 봉화로","JOB_ID":"75","JOB":"정치인","EDU_ID":"221","EDU":"중앙대학교 건설대학원 도시공학과 졸업(공학석사)","CAREER1":"(전)원주시장","CAREER2":"(전)강원도시장군수협의회장","STATUS":"등록"},{"NUM":"8","SG_ID":"20220601","SG_TYPECODE":"2","HUBOID":"100148229","SGG_NAME":"원주시갑","SD_NAME":"강원도","WIW_NAME":"원주시","GIHO":"2","GIHO_SANGSE":"","JD_NAME":"국민의힘","NAME":"박정하","HANJA_NAME":"朴正河","GENDER":"남","BIRTHDAY":"19660926","AGE":"55","ADDR":"강원도 원주시 문막읍 원문로","JOB_ID":"225","JOB":"정당인","EDU_ID":"69","EDU":"고려대학교 대학원 석사과정 행정학과 행정이론전공 수료","CAREER1":"(전)청와대 대변인","CAREER2":"(전)제주도 정무부지사","STATUS":"등록"},{"NUM":"9","SG_ID":"20220601","SG_TYPECODE":"2","HUBOID":"100148332","SGG_NAME":"보령시서천군","SD_NAME":"충청남도","WIW_NAME":"보령시","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"나소열","HANJA_NAME":"羅紹烈","GENDER":"남","BIRTHDAY":"19590516","AGE":"63","ADDR":"충청남도 서천군 서천읍 사곡로75번길","JOB_ID":"225","JOB":"정당인","EDU_ID":"221","EDU":"서강대학교 대학원 정치외교학과 졸업(정치학 석사)","CAREER1":"(전)대통령비서실 자치분권비서관","CAREER2":"(전)충청남도 문화체육부지사","STATUS":"등록"},{"NUM":"10","SG_ID":"20220601","SG_TYPECODE":"2","HUBOID":"100148212","SGG_NAME":"보령시서천군","SD_NAME":"충청남도","WIW_NAME":"보령시","GIHO":"2","GIHO_SANGSE":"","JD ...
# http://apis.data.go.kr/9760000/PofelcddInfoInqireService/getPofelcddRegistSttusInfoInqire?sgId=20220601&sgTypecode=3&resultType=json&serviceKey=EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D
# <class 'str'>
# {"getPofelcddRegistSttusInfoInqire":{"header":{"code":"INFO-00","message":"NORMAL SERVICE"},"item":[{"NUM":"1","SG_ID":"20220601","SG_TYPECODE":"3","HUBOID":"100147796","SGG_NAME":"서울특별시","SD_NAME":"서울특별시","WIW_NAME":"","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"송영길","HANJA_NAME":"宋永吉","GENDER":"남","BIRTHDAY":"19630321","AGE":"59","ADDR":"서울특별시 송파구 거마로3길","JOB_ID":"85","JOB":"변호사","EDU_ID":"68","EDU":"연세대학교 상경대학 경영학과 졸업","CAREER1":"(전)더불어민주당 대표","CAREER2":"(전)국회의원(5선)","STATUS":"등록"},{"NUM":"2","SG_ID":"20220601","SG_TYPECODE":"3","HUBOID":"100149260","SGG_NAME":"서울특별시","SD_NAME":"서울특별시","WIW_NAME":"","GIHO":"2","GIHO_SANGSE":"","JD_NAME":"국민의힘","NAME":"오세훈","HANJA_NAME":"吳世勲","GENDER":"남","BIRTHDAY":"19610104","AGE":"61","ADDR":"서울특별시 광진구 능동로4길","JOB_ID":"73","JOB":"서울특별시장","EDU_ID":"221","EDU":"고려대학교 법학대학원 졸업(법학박사)","CAREER1":"(현)제38대 서울특별시장","CAREER2":"(전)제16대 국회의원","STATUS":"등록"},{"NUM":"3","SG_ID":"20220601","SG_TYPECODE":"3","HUBOID":"100138891","SGG_NAME":"서울특별시","SD_NAME":"서울특별시","WIW_NAME":"","GIHO":"3","GIHO_SANGSE":"","JD_NAME":"정의당","NAME":"권수정","HANJA_NAME":"權秀靜","GENDER":"여","BIRTHDAY":"19730830","AGE":"48","ADDR":"서울특별시 강서구 강서로56나길","JOB_ID":"74","JOB":"서울시의원","EDU_ID":"68","EDU":"충남대학교 물리학과 졸업","CAREER1":"(현)서울시의원","CAREER2":"(전)아시아나항공 노동조합 위원장","STATUS":"등록"},{"NUM":"4","SG_ID":"20220601","SG_TYPECODE":"3","HUBOID":"100144119","SGG_NAME":"서울특별시","SD_NAME":"서울특별시","WIW_NAME":"","GIHO":"4","GIHO_SANGSE":"","JD_NAME":"기본소득당","NAME":"신지혜","HANJA_NAME":"申智惠","GENDER":"여","BIRTHDAY":"19871022","AGE":"34","ADDR":"서울특별시 은평구 통일로72길","JOB_ID":"75","JOB":"정당인","EDU_ID":"68","EDU":"이화여자대학교 사회학과 졸업(복수전공 : 여성학)","CAREER1":"(전)2021 서울특별시장 보궐선거 후보","CAREER2":"(현)기본소득당 상임대표","STATUS":"등록"},{"NUM":"5","SG_ID":"20220601","SG_TYPECODE":"3","HUBOID":"100138508","SGG_NAME":"서울특별시","SD_NAME":"서울특별시","WIW_NAME":"","GIHO":"5","GIHO_SANGSE":"","JD_NAME":"무소속","NAME":"김광종","HANJA_NAME":"金光宗","GENDER":"남","BIRTHDAY":"19620725","AGE":"59","ADDR":"서울특별시 강남구 광평로47길","JOB_ID":"75","JOB":"정치인","EDU_ID":"68","EDU":"서울대학교 외교학과 졸업","CAREER1":"(현)아리랑당 창당추진위원회 대표","CAREER2":"(전)아리랑당 창당준비위원회 대표","STATUS":"등록"},{"NUM":"6","SG_ID":"20220601","SG_TYPECODE":"3","HUBOID":"100146196","SGG_NAME":"부산광역시","SD_NAME":"부산광역시","WIW_NAME":"","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"변성완","HANJA_NAME":"邊城完","GENDER":"남","BIRTHDAY":"19650716","AGE":"56","ADDR":"부산광역시 해운대구 좌동순환로","JOB_ID":"75","JOB":"정당인","EDU_ID":"68","EDU":"고려대학교 정경대학 행정학과 졸업","CAREER1":"(전)노무현대통령 의전행정관","CAREER2":"(전)부산광역시 시장 권한대행","STATUS":"등록"},{"NUM":"7","SG_ID":"20220601","SG_TYPECODE":"3","HUBOID":"100149514","SGG_NAME":"부산광역시","SD_NAME":"부산광역시","WIW_NAME":"","GIHO":"2","GIHO_SANGSE":"","JD_NAME":"국민의힘","NAME":"박형준","HANJA_NAME":"朴亨埈","GENDER":"남","BIRTHDAY":"19600119","AGE":"62","ADDR":"부산광역시 해운대구 달맞이길65번길","JOB_ID":"73","JOB":"부산광역시장","EDU_ID":"221","EDU":"고려대학교 대학원 사회학과 박사과정 졸업(문학박사)","CAREER1":"(전)국회사무총장","CAREER2":"(현)부산광역시장","STATUS":"등록"},{"NUM":"8","SG_ID":"20220601","SG_TYPECODE":"3","HUBOID":"100139837","SGG_NAME":"부산광역시","SD_NAME":"부산광역시","WIW_NAME":"","GIHO":"3","GIHO_SANGSE":"","JD_NAME":"정의당","NAME":"김영진","HANJA_NAME":"金榮珍","GENDER":"남","BIRTHDAY":"19621016","AGE":"59","ADDR":"부산광역시 영도구 해안산책길","JOB_ID":"87","JOB":"회사원","EDU_ID":"65","EDU":"부산공업고등학교 기계과 졸업","CAREER1":"(현) 정의당 부산광역시당 위원장","CAREER2":"(전) 민주노총 부산지역본부 본부장","STATUS":"등록"},{"NUM":"9","SG_ID":"20220601","SG_TYPECODE":"3","HUBOID":"100143589","SGG_NAME":"대구광역시","SD_NAME":"대구광역시","WIW_NAME":"","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"서재헌","HANJA_NAME":"徐載憲","GENDER":"남","BIRTHDAY":"19790425","AGE":"43","ADDR":"대구광역시 동구 율하동로","JOB_ID":"75","JOB":"정당인","EDU_ID":"221","EDU":"영국스트래스클라이드대학교 MBA(경영학 석사)졸업 (2016.9. ~ 2017.11.)","CAREER1":"(전)경기신용보증재단 경영기획본부장(별정직1급대우)","CAREER2":"(전)더불어민주당 대구 동구갑 지역위원장","STATUS":"등록"},{"NUM":"10","SG_ID":"20220601","SG_TYPECODE":"3","HUBOID":"100147274","SGG_NAME":"대구광역시","SD_NAME":"대구광역시","WIW_NAME":"","GIHO":"2","GIHO_SANGSE":"","JD_NAME":"국민의힘","NAME":" ...
# http://apis.data.go.kr/9760000/PofelcddInfoInqireService/getPofelcddRegistSttusInfoInqire?sgId=20220601&sgTypecode=4&resultType=json&serviceKey=EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D
# <class 'str'>
# {"getPofelcddRegistSttusInfoInqire":{"header":{"code":"INFO-00","message":"NORMAL SERVICE"},"item":[{"NUM":"1","SG_ID":"20220601","SG_TYPECODE":"4","HUBOID":"100142311","SGG_NAME":"종로구","SD_NAME":"서울특별시","WIW_NAME":"종로구","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"유찬종","HANJA_NAME":"劉燦鐘","GENDER":"남","BIRTHDAY":"19591120","AGE":"62","ADDR":"서울특별시 종로구 종로","JOB_ID":"75","JOB":"정당인","EDU_ID":"68","EDU":"연세대학교 경법대학 법학과 졸업","CAREER1":"(전)서울특별시의회 의원","CAREER2":"(전)더불어민주당 서울시당 대변인","STATUS":"등록"},{"NUM":"2","SG_ID":"20220601","SG_TYPECODE":"4","HUBOID":"100147847","SGG_NAME":"종로구","SD_NAME":"서울특별시","WIW_NAME":"종로구","GIHO":"2","GIHO_SANGSE":"","JD_NAME":"국민의힘","NAME":"정문헌","HANJA_NAME":"鄭文憲","GENDER":"남","BIRTHDAY":"19660504","AGE":"56","ADDR":"서울특별시 종로구 창의문로5가길","JOB_ID":"75","JOB":"정당인","EDU_ID":"221","EDU":"고려대학교 대학원 정치외교학과 졸업(정치학박사)","CAREER1":"(전)제17,19대 국회의원","CAREER2":"(전)대통령실 외교안보수석실 통일비서관","STATUS":"등록"},{"NUM":"3","SG_ID":"20220601","SG_TYPECODE":"4","HUBOID":"100138578","SGG_NAME":"종로구","SD_NAME":"서울특별시","WIW_NAME":"종로구","GIHO":"4","GIHO_SANGSE":"","JD_NAME":"코리아당","NAME":"류승구","HANJA_NAME":"柳承求","GENDER":"남","BIRTHDAY":"19610728","AGE":"60","ADDR":"서울특별시 종로구 백석동길","JOB_ID":"75","JOB":"코리아당대표","EDU_ID":"58","EDU":"미기재","CAREER1":"(현)대통령직속 민주평화통일자문회의자문위원","CAREER2":"(현)덕(떡)을나누는사람들대표","STATUS":"등록"},{"NUM":"4","SG_ID":"20220601","SG_TYPECODE":"4","HUBOID":"100139558","SGG_NAME":"종로구","SD_NAME":"서울특별시","WIW_NAME":"종로구","GIHO":"5","GIHO_SANGSE":"","JD_NAME":"무소속","NAME":"고남철","HANJA_NAME":"高楠喆","GENDER":"남","BIRTHDAY":"19760822","AGE":"45","ADDR":"서울특별시 종로구 북촌로11나길","JOB_ID":"87","JOB":"동인아이비씨 대표","EDU_ID":"68","EDU":"메릴랜드 대학교(UMBC) 역사학 학사(2002.2~2004.12)","CAREER1":"(현) 대통령직속 국가균형발전위원회 국민소통특별위원","CAREER2":"(현) 사단법인 한국청년스타트업협회 이사","STATUS":"등록"},{"NUM":"5","SG_ID":"20220601","SG_TYPECODE":"4","HUBOID":"100147083","SGG_NAME":"중구","SD_NAME":"서울특별시","WIW_NAME":"중구","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"서양호","HANJA_NAME":"徐良鎬","GENDER":"남","BIRTHDAY":"19671015","AGE":"54","ADDR":"서울특별시 중구 마장로9길","JOB_ID":"75","JOB":"중구청장","EDU_ID":"68","EDU":"숭실대학교 철학과 졸업","CAREER1":"(전)노무현 대통령 청와대 행정관","CAREER2":"(현)중구청장","STATUS":"등록"},{"NUM":"6","SG_ID":"20220601","SG_TYPECODE":"4","HUBOID":"100143217","SGG_NAME":"중구","SD_NAME":"서울특별시","WIW_NAME":"중구","GIHO":"2","GIHO_SANGSE":"","JD_NAME":"국민의힘","NAME":"김길성","HANJA_NAME":"金桔城","GENDER":"남","BIRTHDAY":"19660307","AGE":"56","ADDR":"서울특별시 중구 동호로17길","JOB_ID":"88","JOB":"단국대학교 초빙교수","EDU_ID":"221","EDU":"연세대학교 행정대학원 졸업(행정학 석사)","CAREER1":"(전)대통령실 행정관","CAREER2":"(전)용인도시공사 사장","STATUS":"등록"},{"NUM":"7","SG_ID":"20220601","SG_TYPECODE":"4","HUBOID":"100142623","SGG_NAME":"용산구","SD_NAME":"서울특별시","WIW_NAME":"용산구","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"김철식","HANJA_NAME":"金撤植","GENDER":"남","BIRTHDAY":"19590725","AGE":"62","ADDR":"서울특별시 용산구 이촌로2가길","JOB_ID":"74","JOB":"용산구의원","EDU_ID":"221","EDU":"광운대학교 대학원 졸업(법학박사)","CAREER1":"(현)용산구의회 3선의원","CAREER2":"(현)서울상공회의소 용산구상공회 부회장","STATUS":"등록"},{"NUM":"8","SG_ID":"20220601","SG_TYPECODE":"4","HUBOID":"100138685","SGG_NAME":"용산구","SD_NAME":"서울특별시","WIW_NAME":"용산구","GIHO":"2","GIHO_SANGSE":"","JD_NAME":"국민의힘","NAME":"박희영","HANJA_NAME":"朴熙英","GENDER":"여","BIRTHDAY":"19610527","AGE":"61","ADDR":"서울특별시 용산구 이태원로20가길","JOB_ID":"75","JOB":"정당인","EDU_ID":"68","EDU":"이화여자대학교 정치외교학과 졸업","CAREER1":"(현)국민의힘 용산구 국회의원 권영세 정책특보","CAREER2":"(현)국민의힘 용산구당협 부동산특별위원회 위원장","STATUS":"등록"},{"NUM":"9","SG_ID":"20220601","SG_TYPECODE":"4","HUBOID":"100138874","SGG_NAME":"용산구","SD_NAME":"서울특별시","WIW_NAME":"용산구","GIHO":"4","GIHO_SANGSE":"","JD_NAME":"무소속","NAME":"박규정","HANJA_NAME":"朴圭貞","GENDER":"남","BIRTHDAY":"19590907","AGE":"62","ADDR":"서울특별시 용산구 이촌로65길","JOB_ID":"225","JOB":"용산미래연구원 원장","EDU_ID":"69","EDU":"서강대학교 대학원 수료(경제학과)","CAREER1":"(현)용산미래연구원장","CAREER2":"(전)새누리당 중앙당 부대변인","STATUS":"등록"},{"NUM":"10","SG_ID":"20220601","SG_TYPECODE":"4","HUBOID":"100148289","SGG_NAME":"성동구","SD_NAME":"서울특별시","WIW_NAME":"성동구","GIHO":"1","GIHO_SANGSE":"" ...
# http://apis.data.go.kr/9760000/PofelcddInfoInqireService/getPofelcddRegistSttusInfoInqire?sgId=20220601&sgTypecode=5&resultType=json&serviceKey=EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D
# <class 'str'>
# {"getPofelcddRegistSttusInfoInqire":{"header":{"code":"INFO-00","message":"NORMAL SERVICE"},"item":[{"NUM":"1","SG_ID":"20220601","SG_TYPECODE":"5","HUBOID":"100144350","SGG_NAME":"종로구제1선거구","SD_NAME":"서울특별시","WIW_NAME":"종로구","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"채행숙","HANJA_NAME":"蔡幸潚","GENDER":"여","BIRTHDAY":"19671023","AGE":"54","ADDR":"서울특별시 종로구 진흥로22길","JOB_ID":"75","JOB":"정당인","EDU_ID":"221","EDU":"성균관대학교 사회복지대학원 사회복지학과 졸업(사회복지학석사)","CAREER1":"(현)더불어민주당 부대변인","CAREER2":"(현)종로구체육회 부회장","STATUS":"등록"},{"NUM":"2","SG_ID":"20220601","SG_TYPECODE":"5","HUBOID":"100148176","SGG_NAME":"종로구제1선거구","SD_NAME":"서울특별시","WIW_NAME":"종로구","GIHO":"2","GIHO_SANGSE":"","JD_NAME":"국민의힘","NAME":"윤종복","HANJA_NAME":"尹鍾福","GENDER":"남","BIRTHDAY":"19480422","AGE":"74","ADDR":"서울특별시 종로구 계동길","JOB_ID":"75","JOB":"정당인","EDU_ID":"66","EDU":"한국방송통신대학교 법학과 1학년 제적(2006.03~2012.03)","CAREER1":"(전)제8대 종로구의회의원","CAREER2":"(전)국민의힘 종로지구당 홍보위원장","STATUS":"등록"},{"NUM":"3","SG_ID":"20220601","SG_TYPECODE":"5","HUBOID":"100146182","SGG_NAME":"종로구제2선거구","SD_NAME":"서울특별시","WIW_NAME":"종로구","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"임종국","HANJA_NAME":"林鍾國","GENDER":"남","BIRTHDAY":"19640531","AGE":"58","ADDR":"서울특별시 종로구 혜화로2길","JOB_ID":"74","JOB":"서울특별시의회 의원","EDU_ID":"68","EDU":"한국외국어대학교 영어과 졸업","CAREER1":"(현)서울특별시의회 의원","CAREER2":"(현)더불어민주당 정책위 부의장","STATUS":"등록"},{"NUM":"4","SG_ID":"20220601","SG_TYPECODE":"5","HUBOID":"100146018","SGG_NAME":"종로구제2선거구","SD_NAME":"서울특별시","WIW_NAME":"종로구","GIHO":"2","GIHO_SANGSE":"","JD_NAME":"국민의힘","NAME":"이서은","HANJA_NAME":"李庶溵","GENDER":"여","BIRTHDAY":"19750213","AGE":"47","ADDR":"서울특별시 종로구 낙산길","JOB_ID":"87","JOB":"(주)위보코리아 부대표","EDU_ID":"68","EDU":"을지대학교 임상병리학과 졸업","CAREER1":"(현)국내(KAC)·국제세포병리학(IAC)","CAREER2":"(현)국민의힘 중앙위원회 상임고문","STATUS":"등록"},{"NUM":"5","SG_ID":"20220601","SG_TYPECODE":"5","HUBOID":"100146134","SGG_NAME":"중구제1선거구","SD_NAME":"서울특별시","WIW_NAME":"중구","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"박순규","HANJA_NAME":"朴淳圭","GENDER":"남","BIRTHDAY":"19600719","AGE":"61","ADDR":"서울특별시 중구 다산로38길","JOB_ID":"74","JOB":"서울특별시의회의원","EDU_ID":"220","EDU":"서울시립대학교 도시과학대학원 도시행정학과 재학 중","CAREER1":"(현)서울특별시의회의원","CAREER2":"(현)더불어민주당 정책위원회 부의장","STATUS":"등록"},{"NUM":"6","SG_ID":"20220601","SG_TYPECODE":"5","HUBOID":"100146621","SGG_NAME":"중구제1선거구","SD_NAME":"서울특별시","WIW_NAME":"중구","GIHO":"2","GIHO_SANGSE":"","JD_NAME":"국민의힘","NAME":"박영한","HANJA_NAME":"朴榮漢","GENDER":"남","BIRTHDAY":"19591020","AGE":"62","ADDR":"서울특별시 중구 청구로10길","JOB_ID":"225","JOB":"정당인","EDU_ID":"221","EDU":"동국대학교 대학원 국제다문화학과 졸업(철학박사)","CAREER1":"(전)제7ㆍ8대 서울특별시 중구의회의원","CAREER2":"(현)국민의힘 서울시당 노동위원회 중ㆍ성동구을 지회장","STATUS":"등록"},{"NUM":"7","SG_ID":"20220601","SG_TYPECODE":"5","HUBOID":"100146484","SGG_NAME":"중구제2선거구","SD_NAME":"서울특별시","WIW_NAME":"중구","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"이혜영","HANJA_NAME":"李惠英","GENDER":"여","BIRTHDAY":"19731120","AGE":"48","ADDR":"서울특별시 중구 다산로20길","JOB_ID":"225","JOB":"정당인","EDU_ID":"220","EDU":"연세대학교 행정대학원 사회복지전공 석사과정 제5학기 휴학중","CAREER1":"(전)제8대 서울특별시 중구의회의원","CAREER2":"(전)휴먼컨설팅그룹 솔루션Div. 이사","STATUS":"등록"},{"NUM":"8","SG_ID":"20220601","SG_TYPECODE":"5","HUBOID":"100145921","SGG_NAME":"중구제2선거구","SD_NAME":"서울특별시","WIW_NAME":"중구","GIHO":"2","GIHO_SANGSE":"","JD_NAME":"국민의힘","NAME":"옥재은","HANJA_NAME":"玉在恩","GENDER":"여","BIRTHDAY":"19701015","AGE":"51","ADDR":"서울특별시 중구 다산로","JOB_ID":"88","JOB":"협성대학교 객원교수","EDU_ID":"69","EDU":"동국대학교 대학원 국제다문화학과 박사과정 수료","CAREER1":"(전)제20대 대통령직 인수위원회(사회복지문화분과)자문위원","CAREER2":"(현)국민의힘 서울시당 대변인","STATUS":"등록"},{"NUM":"9","SG_ID":"20220601","SG_TYPECODE":"5","HUBOID":"100146989","SGG_NAME":"용산구제1선거구","SD_NAME":"서울특별시","WIW_NAME":"용산구","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"안태홍","HANJA_NAME":"安泰弘","GENDER":"남","BIRTHDAY":"19850510","AGE":"37","ADDR":"서울특별시 용산구 소월로2다길","JOB_ID":"225","JOB":"서울로 마을닥터 목공 협동조합 이사장","EDU_ID":"221","EDU":"서울대학교 환경대학원 졸업(조경학 석사)","CAREER1":"(전) 서울대학교 환경대학원 학생회장","CAREER2":"(현) 더불어민주당 전국청년당 정책위 청년주거복지위원장","STATU ...
# http://apis.data.go.kr/9760000/PofelcddInfoInqireService/getPofelcddRegistSttusInfoInqire?sgId=20220601&sgTypecode=6&resultType=json&serviceKey=EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D
# <class 'str'>
# {"getPofelcddRegistSttusInfoInqire":{"header":{"code":"INFO-00","message":"NORMAL SERVICE"},"item":[{"NUM":"1","SG_ID":"20220601","SG_TYPECODE":"6","HUBOID":"100145851","SGG_NAME":"종로구가선거구","SD_NAME":"서울특별시","WIW_NAME":"종로구","GIHO":"1","GIHO_SANGSE":"가","JD_NAME":"더불어민주당","NAME":"여봉무","HANJA_NAME":"呂捧戊","GENDER":"남","BIRTHDAY":"19520319","AGE":"70","ADDR":"서울특별시 종로구 옥인길","JOB_ID":"75","JOB":"정당인","EDU_ID":"67","EDU":"한국방송통신대학교 행정학과 1학년 재학중","CAREER1":"(현)종로구의회 의장","CAREER2":"(전)종로구의회 건설복지위원장","STATUS":"등록"},{"NUM":"2","SG_ID":"20220601","SG_TYPECODE":"6","HUBOID":"100146179","SGG_NAME":"종로구가선거구","SD_NAME":"서울특별시","WIW_NAME":"종로구","GIHO":"1","GIHO_SANGSE":"나","JD_NAME":"더불어민주당","NAME":"김금옥","HANJA_NAME":"金庈屋","GENDER":"남","BIRTHDAY":"19631130","AGE":"58","ADDR":"서울특별시 종로구 사직로8길","JOB_ID":"75","JOB":"정당인","EDU_ID":"220","EDU":"국민대학교 정치대학원 의회·지방정치전공 석사과정 재학중","CAREER1":"(현) 종로구의회 운영위원장","CAREER2":"(전) 더불어민주당 중앙당 소상공인특별위원회 부위원장","STATUS":"등록"},{"NUM":"3","SG_ID":"20220601","SG_TYPECODE":"6","HUBOID":"100143807","SGG_NAME":"종로구가선거구","SD_NAME":"서울특별시","WIW_NAME":"종로구","GIHO":"2","GIHO_SANGSE":"가","JD_NAME":"국민의힘","NAME":"이응주","HANJA_NAME":"李應周","GENDER":"남","BIRTHDAY":"19620807","AGE":"59","ADDR":"서울특별시 종로구 통일로18길","JOB_ID":"87","JOB":"법률사무직(법무법인 실장)","EDU_ID":"68","EDU":"단국대학교 행정학과 졸업","CAREER1":"(현)국민의힘 종로구당협 운영위원","CAREER2":"(전) 서울지방변호사사무직원회 회장","STATUS":"등록"},{"NUM":"4","SG_ID":"20220601","SG_TYPECODE":"6","HUBOID":"100145741","SGG_NAME":"종로구가선거구","SD_NAME":"서울특별시","WIW_NAME":"종로구","GIHO":"2","GIHO_SANGSE":"나","JD_NAME":"국민의힘","NAME":"최경애","HANJA_NAME":"崔敬愛","GENDER":"여","BIRTHDAY":"19580820","AGE":"63","ADDR":"서울특별시 종로구 통일로","JOB_ID":"75","JOB":"정당인","EDU_ID":"221","EDU":"경기대학교 사회복지대학원 사회복지학 석사","CAREER1":"(현)제8대 종로구의회의원","CAREER2":"(현)제8대 국민의힘 서울시당 부위원장","STATUS":"등록"},{"NUM":"5","SG_ID":"20220601","SG_TYPECODE":"6","HUBOID":"100146224","SGG_NAME":"종로구나선거구","SD_NAME":"서울특별시","WIW_NAME":"종로구","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"정재호","HANJA_NAME":"鄭載鎬","GENDER":"남","BIRTHDAY":"19631002","AGE":"58","ADDR":"서울특별시 종로구 세검정로9길","JOB_ID":"75","JOB":"정당인","EDU_ID":"220","EDU":"상명대학교 대학원 디지털이미지학과 석사 과정 재학중","CAREER1":"(현) 종로구의회 행정문화위원장","CAREER2":"(전) 종로구시설관리공단 비상임이사","STATUS":"등록"},{"NUM":"6","SG_ID":"20220601","SG_TYPECODE":"6","HUBOID":"100142595","SGG_NAME":"종로구나선거구","SD_NAME":"서울특별시","WIW_NAME":"종로구","GIHO":"2","GIHO_SANGSE":"가","JD_NAME":"국민의힘","NAME":"김하영","HANJA_NAME":"金河永","GENDER":"여","BIRTHDAY":"19740519","AGE":"48","ADDR":"서울특별시 종로구 진흥로21길","JOB_ID":"75","JOB":"정당인","EDU_ID":"220","EDU":"중앙대학교 행정대학원 복지행정학과 재학중","CAREER1":"(전)서울 세검정초등학교 학부모회장","CAREER2":"(현)국민의힘 서울시당 여성위원회 수석부위원장","STATUS":"등록"},{"NUM":"7","SG_ID":"20220601","SG_TYPECODE":"6","HUBOID":"100142393","SGG_NAME":"종로구나선거구","SD_NAME":"서울특별시","WIW_NAME":"종로구","GIHO":"2","GIHO_SANGSE":"나","JD_NAME":"국민의힘","NAME":"김훈태","HANJA_NAME":"金勳泰","GENDER":"남","BIRTHDAY":"19660316","AGE":"56","ADDR":"서울특별시 종로구 평창문화로","JOB_ID":"75","JOB":"정당인","EDU_ID":"68","EDU":"서원대학교 지리교육과 졸업","CAREER1":"(현)국민생활도움센터 대표","CAREER2":"(전)한나라당 중앙청년위원회 운영위원","STATUS":"등록"},{"NUM":"8","SG_ID":"20220601","SG_TYPECODE":"6","HUBOID":"100146417","SGG_NAME":"종로구다선거구","SD_NAME":"서울특별시","WIW_NAME":"종로구","GIHO":"1","GIHO_SANGSE":"가","JD_NAME":"더불어민주당","NAME":"이륜구","HANJA_NAME":"李倫求","GENDER":"남","BIRTHDAY":"19880307","AGE":"34","ADDR":"서울특별시 종로구 삼일대로","JOB_ID":"225","JOB":"전통이음 대표","EDU_ID":"220","EDU":"경희대학교 대학원 국어국문학과 박사과정 재학중 (고전문학)","CAREER1":"(전)종로경찰서 선도심의위원","CAREER2":"(현)사단법인 평화문화재단 사무국장","STATUS":"등록"},{"NUM":"9","SG_ID":"20220601","SG_TYPECODE":"6","HUBOID":"100145794","SGG_NAME":"종로구다선거구","SD_NAME":"서울특별시","WIW_NAME":"종로구","GIHO":"1","GIHO_SANGSE":"나","JD_NAME":"더불어민주당","NAME":"전영준","HANJA_NAME":"田榮俊","GENDER":"남","BIRTHDAY":"19590821","AGE":"62","ADDR":"서울특별시 종로구 성균관로5길","JOB_ID":"75","JOB":"정당인","EDU_ID":"58","EDU":"미기재","CAREER1":"(현)제8대 종로구의회 건설복지위원회 부위원장","CAREER2":"(전)종로구 예산결산특별위원회 위원장","STATUS":"등록"},{"NUM":"10","SG_ID":"20220601","SG_TYPECODE":"6","HUBOID":"100145140","SG ...
# http://apis.data.go.kr/9760000/PofelcddInfoInqireService/getPofelcddRegistSttusInfoInqire?sgId=20220601&sgTypecode=7&resultType=json&serviceKey=EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D
# <class 'str'>
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <result>
#     <code>INFO-03</code>
#     <message>데이터가 정보가 없습니다. 활용문서를 확인해 주시기 바랍니다.</message>
# </result>
#
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <result>
#     <code>INFO-03</code>
#     <message>데이터가 정보가 없습니다. 활용문서를 확인해 주시기 바랍니다.</message>
# </result>
#
# http://apis.data.go.kr/9760000/PofelcddInfoInqireService/getPofelcddRegistSttusInfoInqire?sgId=20220601&sgTypecode=8&resultType=json&serviceKey=EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D
# <class 'str'>
# {"getPofelcddRegistSttusInfoInqire":{"header":{"code":"INFO-00","message":"NORMAL SERVICE"},"item":[{"NUM":"1","SG_ID":"20220601","SG_TYPECODE":"8","HUBOID":"100149458","SGG_NAME":"서울특별시","SD_NAME":"서울특별시","WIW_NAME":"","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"기본소득당","NAME":"김진서","HANJA_NAME":"金辰書","GENDER":"여","BIRTHDAY":"19970617","AGE":"24","ADDR":"서울특별시 은평구 통일로66길","JOB_ID":"225","JOB":"사회운동가","EDU_ID":"68","EDU":"성균관대학교 미디어커뮤니케이션학과 졸업","CAREER1":"(전) 대학 페미니스트 공동체유니브페미 대표","CAREER2":"(전) 서울퀴어문화축제 조직위원회 통번역팀 활동가","STATUS":"등록"},{"NUM":"2","SG_ID":"20220601","SG_TYPECODE":"8","HUBOID":"100150016","SGG_NAME":"서울특별시","SD_NAME":"서울특별시","WIW_NAME":"","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"진보당","NAME":"노우정","HANJA_NAME":"盧禹妌","GENDER":"여","BIRTHDAY":"19700728","AGE":"51","ADDR":"서울특별시 은평구 통일로59길","JOB_ID":"225","JOB":"요양보호사","EDU_ID":"68","EDU":"강남사회복지학교(현 강남대학교) 유아교육학과 졸업","CAREER1":"(현)민주노총 전국요양서비스노동조합 위원장","CAREER2":"(현)서울시사회서비스원 은평종합재가센터 요양보호사","STATUS":"등록"},{"NUM":"3","SG_ID":"20220601","SG_TYPECODE":"8","HUBOID":"100149785","SGG_NAME":"서울특별시","SD_NAME":"서울특별시","WIW_NAME":"","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"한류연합당","NAME":"설윤서","HANJA_NAME":"薛潤鉏","GENDER":"여","BIRTHDAY":"19820315","AGE":"40","ADDR":"서울특별시 강남구 개포로26길","JOB_ID":"75","JOB":"정당인","EDU_ID":"68","EDU":"광운대학교 국어국문학과 졸업","CAREER1":"(현)한류연합당 사무총장","CAREER2":"(현)월드마스터위원회 총괄처장","STATUS":"등록"},{"NUM":"4","SG_ID":"20220601","SG_TYPECODE":"8","HUBOID":"100150335","SGG_NAME":"서울특별시","SD_NAME":"서울특별시","WIW_NAME":"","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"정의당","NAME":"오현주","HANJA_NAME":"吳賢珠","GENDER":"여","BIRTHDAY":"19791003","AGE":"42","ADDR":"서울특별시 마포구 동교로","JOB_ID":"75","JOB":"정당인","EDU_ID":"221","EDU":"이화여자대학교 일반대학원 여성학과 석사수료","CAREER1":"(현)정의당 마포구지역위원장","CAREER2":"(전)정의당 중앙당 대변인","STATUS":"등록"},{"NUM":"5","SG_ID":"20220601","SG_TYPECODE":"8","HUBOID":"100150022","SGG_NAME":"서울특별시","SD_NAME":"서울특별시","WIW_NAME":"","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"녹색당","NAME":"이상현","HANJA_NAME":"李尙炫","GENDER":"여","BIRTHDAY":"19861005","AGE":"35","ADDR":"서울특별시 중랑구 신내역로1길","JOB_ID":"225","JOB":"시민사회활동가","EDU_ID":"68","EDU":"한국외국어대학교 일본학대학 일본어과 졸업","CAREER1":"(현)서울녹색당공동운영위원장","CAREER2":"(현)서울기후위기비상행동 정책교육팀장","STATUS":"등록"},{"NUM":"6","SG_ID":"20220601","SG_TYPECODE":"8","HUBOID":"100150334","SGG_NAME":"서울특별시","SD_NAME":"서울특별시","WIW_NAME":"","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"이소라","HANJA_NAME":"李昭羅","GENDER":"여","BIRTHDAY":"19940830","AGE":"27","ADDR":"서울특별시 동대문구 무학로49길","JOB_ID":"75","JOB":"정당인","EDU_ID":"68","EDU":"성신여자대학교 정치외교학과 졸업(사회복지학과 복수전공)","CAREER1":"(전) 더불어민주당 서울특별시당 대학생위원장","CAREER2":"(전) 성북구청장 정책비서","STATUS":"등록"},{"NUM":"7","SG_ID":"20220601","SG_TYPECODE":"8","HUBOID":"100150593","SGG_NAME":"서울특별시","SD_NAME":"서울특별시","WIW_NAME":"","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"통일한국당","NAME":"이재숙","HANJA_NAME":"李在婌","GENDER":"여","BIRTHDAY":"19640702","AGE":"57","ADDR":"서울특별시 강동구 성내로","JOB_ID":"75","JOB":"정당인","EDU_ID":"68","EDU":"이화여자대학교 정치외교학과 졸업","CAREER1":"(전)강남사임당 어린이집 교사","CAREER2":"(현)통일한국당 정책위원회 부위원장","STATUS":"등록"},{"NUM":"8","SG_ID":"20220601","SG_TYPECODE":"8","HUBOID":"100149754","SGG_NAME":"서울특별시","SD_NAME":"서울특별시","WIW_NAME":"","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"독도당","NAME":"조순애","HANJA_NAME":"趙順愛","GENDER":"여","BIRTHDAY":"19490110","AGE":"73","ADDR":"서울특별시 중구 청구로","JOB_ID":"225","JOB":"주부","EDU_ID":"58","EDU":"미기재","CAREER1":"미기재","CAREER2":"","STATUS":"등록"},{"NUM":"9","SG_ID":"20220601","SG_TYPECODE":"8","HUBOID":"100150333","SGG_NAME":"서울특별시","SD_NAME":"서울특별시","WIW_NAME":"","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"국민의힘","NAME":"황유정","HANJA_NAME":"黃裕晶","GENDER":"여","BIRTHDAY":"19611226","AGE":"60","ADDR":"서울특별시 강남구 남부순환로381길","JOB_ID":"88","JOB":"명지대학교 겸임교수","EDU_ID":"221","EDU":"이화여자대학교 대학원 문학박사(동아시아학연구사회연구전공)","CAREER1":"(전)대통령비서실 행정관","CAREER2":"(전)독립기념관 이사(비상임)","STATUS":"등록"},{"NUM":"10","SG_ID":"20220601","SG_TYPECODE":"8","HUBOID":"100149459","SGG_NAME":"서울특별시","SD_NAME":"서울특별시","WIW_NAME":"","GIHO":"2","GIHO_SANGSE":"","JD_NAME":"기본소득당" ...
# http://apis.data.go.kr/9760000/PofelcddInfoInqireService/getPofelcddRegistSttusInfoInqire?sgId=20220601&sgTypecode=9&resultType=json&serviceKey=EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D
# <class 'str'>
# {"getPofelcddRegistSttusInfoInqire":{"header":{"code":"INFO-00","message":"NORMAL SERVICE"},"item":[{"NUM":"1","SG_ID":"20220601","SG_TYPECODE":"9","HUBOID":"100149105","SGG_NAME":"종로구","SD_NAME":"서울특별시","WIW_NAME":"종로구","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"국민의힘","NAME":"박희연","HANJA_NAME":"朴熙燕","GENDER":"여","BIRTHDAY":"19731225","AGE":"48","ADDR":"서울특별시 종로구 혜화로11길","JOB_ID":"75","JOB":"정당인","EDU_ID":"221","EDU":"고려대학교 정책대학원 경제학석사(국토경제)","CAREER1":"(현)국민의힘 중앙여성위원회 부위원장","CAREER2":"(현)혜화동지역사회보장협의체 위원장","STATUS":"등록"},{"NUM":"2","SG_ID":"20220601","SG_TYPECODE":"9","HUBOID":"100148868","SGG_NAME":"종로구","SD_NAME":"서울특별시","WIW_NAME":"종로구","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"이미자","HANJA_NAME":"李美子","GENDER":"여","BIRTHDAY":"19600125","AGE":"62","ADDR":"서울특별시 종로구 동숭길","JOB_ID":"224","JOB":"무직","EDU_ID":"68","EDU":"학점인정 등에 관한 법률에 의하여 총신대학교 사회복지학사 학위 취득","CAREER1":"(현)더불어민주당 종로구지역위원회 여성위원장","CAREER2":"(현)민주평화통일자문회의 종로구위원회 부회장","STATUS":"등록"},{"NUM":"3","SG_ID":"20220601","SG_TYPECODE":"9","HUBOID":"100149410","SGG_NAME":"중구","SD_NAME":"서울특별시","WIW_NAME":"중구","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"박민정","HANJA_NAME":"朴玟挺","GENDER":"여","BIRTHDAY":"19940221","AGE":"28","ADDR":"서울특별시 중구 동호로24길","JOB_ID":"225","JOB":"더불어민주당 박성준 의원실 비서관","EDU_ID":"66","EDU":"고려대학교 공과대학 신소재공학부 중퇴(2013.03.01.-2018.02.26)","CAREER1":"(전)더불어민주당 중구성동구을 지역위원회 비서","CAREER2":"(현)박성준의원실 비서관(9급 상당)","STATUS":"등록"},{"NUM":"4","SG_ID":"20220601","SG_TYPECODE":"9","HUBOID":"100149409","SGG_NAME":"중구","SD_NAME":"서울특별시","WIW_NAME":"중구","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"국민의힘","NAME":"양은미","HANJA_NAME":"梁銀美","GENDER":"여","BIRTHDAY":"19730210","AGE":"49","ADDR":"서울특별시 중구 동호로25가길","JOB_ID":"225","JOB":"정당인","EDU_ID":"68","EDU":"경희사이버대학교 상담심리학과 졸업","CAREER1":"(전)제7대 중구의원 행정보건위원장","CAREER2":"","STATUS":"등록"},{"NUM":"5","SG_ID":"20220601","SG_TYPECODE":"9","HUBOID":"100149330","SGG_NAME":"용산구","SD_NAME":"서울특별시","WIW_NAME":"용산구","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"윤정회","HANJA_NAME":"尹正會","GENDER":"여","BIRTHDAY":"19840307","AGE":"38","ADDR":"서울특별시 용산구 이촌로34길","JOB_ID":"224","JOB":"무직","EDU_ID":"221","EDU":"고려대학교 정책대학원 졸업(정치학 석사)","CAREER1":"(전)성동구청 소통담당관","CAREER2":"(전)진영 국회의원 비서","STATUS":"등록"},{"NUM":"6","SG_ID":"20220601","SG_TYPECODE":"9","HUBOID":"100149341","SGG_NAME":"용산구","SD_NAME":"서울특별시","WIW_NAME":"용산구","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"국민의힘","NAME":"이인호","HANJA_NAME":"李仁鎬","GENDER":"여","BIRTHDAY":"19570510","AGE":"65","ADDR":"서울특별시 용산구 이촌로22길","JOB_ID":"75","JOB":"정당인","EDU_ID":"67","EDU":"국제사이버대학교 재학중(사회복지학)","CAREER1":"(현)국민의힘 용산구 당원협의회 여성위원장","CAREER2":"(현)용산구 여성경제인연합회 회장","STATUS":"등록"},{"NUM":"7","SG_ID":"20220601","SG_TYPECODE":"9","HUBOID":"100149942","SGG_NAME":"성동구","SD_NAME":"서울특별시","WIW_NAME":"성동구","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"더불어민주당","NAME":"이영심","HANJA_NAME":"李映心","GENDER":"여","BIRTHDAY":"19601103","AGE":"61","ADDR":"서울특별시 성동구 마조로14가길","JOB_ID":"225","JOB":"주부","EDU_ID":"765","EDU":"성화대학 아동복지계열 사회복지과 졸업","CAREER1":"(전)성동구 여성단체연합회장","CAREER2":"(전)성동구 새마을부녀회장","STATUS":"등록"},{"NUM":"8","SG_ID":"20220601","SG_TYPECODE":"9","HUBOID":"100149920","SGG_NAME":"성동구","SD_NAME":"서울특별시","WIW_NAME":"성동구","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"국민의힘","NAME":"이현숙","HANJA_NAME":"李賢淑","GENDER":"여","BIRTHDAY":"19651116","AGE":"56","ADDR":"서울특별시 성동구 사근동길","JOB_ID":"225","JOB":"스마트해법영어 초롱엘리트 대표","EDU_ID":"765","EDU":"한양여자전문대학 유아교육과 졸업","CAREER1":"(현)한양사범부속고등학교 총 동문회장","CAREER2":"(전)한양여자대학 총 동문회장","STATUS":"등록"},{"NUM":"9","SG_ID":"20220601","SG_TYPECODE":"9","HUBOID":"100149205","SGG_NAME":"광진구","SD_NAME":"서울특별시","WIW_NAME":"광진구","GIHO":"1","GIHO_SANGSE":"","JD_NAME":"국민의힘","NAME":"고상순","HANJA_NAME":"高尙順","GENDER":"여","BIRTHDAY":"19620808","AGE":"59","ADDR":"서울특별시 광진구 자양로6길","JOB_ID":"75","JOB":"정당인","EDU_ID":"221","EDU":"서강대학교 공공정책대학원 사회문화정책학과 졸업(행정학석사)","CAREER1":"(현)국민의힘 서울시당 여성위원회 부위원장","CAREER2":"(전)국민의힘 광진구을 당원협의회 여성부장","STATUS":"등록"},{"NUM":"10","SG_ID":"20220601","SG_TYPECODE":"9","HUBOID":"100149 ...

# %%
df['HUBOID'].value_counts()
# Out:
# 100147796    1
# 100149260    1
# 100138891    1
# 100144119    1
# 100138508    1
# 100146196    1
# 100149514    1
# 100139837    1
# 100143589    1
# 100147274    1
# Name: HUBOID, dtype: int64

# %% [markdown]
# # 선거공약

# %%
from urllib.request import Request,urlopen
from urllib.parse import urlencode,quote_plus
import pandas as pd
import json

skey = 'EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D'
resultType = 'json'
sgId = '20220601'
sgTypecode = '3' #선거공약서 제출코드(SgTypecode) : 1(대통령선거), 3(시∙도시자선거),4(구∙시∙군의장선거), 11(교육감선거)
cnddtId = '100147274'

url = 'http://apis.data.go.kr/9760000/ElecPrmsInfoInqireService/getCnddtElecPrmsInfoInqire'
params = f'?resultType={resultType}&sgId={sgId}&sgTypecode={sgTypecode}&cnddtId={cnddtId}&serviceKey={skey}'
query = url + params
#print(query)

request = Request(query)
request.get_method = lambda:'GET'
response_body = urlopen(request).read()
#print(response_body)

response_dict = json.loads(response_body.decode('utf-8'))
response_dict
items = response_dict['getCnddtElecPrmsInfoInqire']['item']

df = pd.DataFrame(items)
df
# Out:
#   num      sgId sgTypecode    cnddtId sggName sidoName wiwName partyName  \
# 0   1  20220601          3  100147274   대구광역시    대구광역시              국민의힘
#
#   krName cnName  ... prmsTitle8 prmmCont8 prmsOrd9 prmsRealmName9 prmsTitle9  \
# 0    홍준표    洪準杓  ...
#
#   prmmCont9 prmsOrd10 prmsRealmName10 prmsTitle10 prmmCont10
# 0
#
# [1 rows x 51 columns]
